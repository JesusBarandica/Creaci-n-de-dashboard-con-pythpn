# %% [markdown]
# <a href="https://colab.research.google.com/github/JesusBarandica/Creacion-de-dashboard-con-python/blob/main/Entendimiento_de_datos_db_finagro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**1- Entendimiento de los datos**

# %% [markdown]
# ##**1.1- Integración de datos (pandas y PostgreSQL)**
# Se sube dataset a una base de datos de postgreSQL, para facilitar procesamiento y facil integración con el notebook de python, se realiza conexión a la base de datos y se le tabla por medio de SQL en pandas.

# %%
# !pip install psycopg2
# !pip install sqlalchemy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: psycopg2 in /usr/local/lib/python3.8/dist-packages (2.9.5)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.8/dist-packages (1.4.45)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.8/dist-packages (from sqlalchemy) (2.0.1)

# %%
import pandas as pd
from sqlalchemy import create_engine
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

# Configuraciones de Matplotlib
# %matplotlib inline   
plt.rcParams['figure.dpi'] = 110

# %%
# Estilo por defecto para notebooks.
sns.set_theme('notebook')

# %%
#conexión a plataforma donde se aloja la base de datos, creación de objeto engine para creación de consultas

PG_STRING = "postgresql://jesusbarandica:v2_3wU2Q_dpxWLyMbkAWeJjQxz2vtisc@db.bit.io/jesusbarandica/testdb"
engine = create_engine(PG_STRING)

# %%
# consulta para visualizar tabla completa y abrir con pandas
query = """
SELECT *
FROM colocacion
;
"""
with engine.connect() as conn:
    data = pd.read_sql(query, conn)

# %%
data.head(5)
# Out:
#      año  mes fuente Colocacion  Id Tipo Prod Tipo Productor Valor Inversion  \
# 0  2,021    4       REDESCUENTO             1        MEDIANO      24,000,000
# 1  2,021    4       REDESCUENTO             0        PEQUEÑO       6,000,000
# 2  2,021    4       REDESCUENTO             0        PEQUEÑO       8,200,000
# 3  2,021    4       REDESCUENTO             0        PEQUEÑO      15,000,000
# 4  2,021    4       REDESCUENTO             0        PEQUEÑO      10,000,000
#
#    colocacion  ID Depto Departamento Inversion Id Munic  ... Linea de Credito  \
# 0  23,655,000         5              ANTIOQUIA    5,237  ...        Inversión
# 1   5,000,000        68              SANTANDER   68,169  ...        Inversión
# 2   8,200,000        41                  HUILA   41,807  ...        Inversión
# 3  15,000,000        85               CASANARE   85,139  ...        Inversión
# 4  10,000,000        85               CASANARE   85,300  ...        Inversión
#
#                Linea de Produccion  ID Rubro  \
# 0           COMPRA DE ANIMALES (I)   253,061
# 1                     SIEMBRAS (I)   151,310
# 2  INFRAEST Y ADECU DE TIERRAS (I)   347,050
# 3                     SIEMBRAS (I)   151,050
# 4                     SIEMBRAS (I)   141,060
#
#                            Destino de Credito genero % FAG  Vlr Inic Garantia  \
# 0  253061 Retención de vientres ganado bovino      H   NaN               None
# 1                             151310 Aguacate      H  80.0          4,000,000
# 2  347050 Construcción beneficiaderos de café      H  80.0          6,560,000
# 3                                151050 Cacao      H  80.0         12,000,000
# 4                        141060 Caña panelera      M  80.0          8,000,000
#
#     latitud   longitud cantidad
# 0  6.500000 -75.333333        1
# 1  7.300000 -72.966667        1
# 2  2.000000 -75.916667        1
# 3  4.833333 -72.333333        1
# 4  4.853611 -73.043056        1
#
# [5 rows x 27 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850141 entries, 0 to 850140
# Data columns (total 27 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   año                                    850141 non-null  object
#  1   mes                                    850141 non-null  int64
#  2   fuente Colocacion                      850141 non-null  object
#  3   Id Tipo Prod                           850141 non-null  int64
#  4   Tipo Productor                         850141 non-null  object
#  5   Valor Inversion                        850141 non-null  object
#  6   colocacion                             850141 non-null  object
#  7   ID Depto                               850141 non-null  int64
#  8   Departamento Inversion                 850141 non-null  object
#  9   Id Munic                               850141 non-null  object
#  10  Municipio Inversion                    850141 non-null  object
#  11  Municipio de PostConflico?             850141 non-null  object
#  12  depcol                                 850141 non-null  int64
#  13  Departamento de Colocacion de Credito  850141 non-null  object
#  14  muncol                                 850141 non-null  object
#  15  Municipio Colocacion de Credito        850141 non-null  object
#  16  plazo                                  850141 non-null  int64
#  17  Linea de Credito                       850141 non-null  object
#  18  Linea de Produccion                    850141 non-null  object
#  19  ID Rubro                               850141 non-null  object
#  20  Destino de Credito                     850141 non-null  object
#  21  genero                                 850141 non-null  object
#  22  % FAG                                  543262 non-null  float64
#  23  Vlr Inic Garantia                      543262 non-null  object
#  24  latitud                                850141 non-null  float64
#  25  longitud                               850141 non-null  float64
#  26  cantidad                               850141 non-null  int64
# dtypes: float64(3), int64(6), object(18)
# memory usage: 175.1+ MB

# %% [markdown]
# ##**1.2- Detalles del formato de los tipo de variables**
#
# Se realiza revisión inicial de los formato de cada una de las variables:
#
# | Variables | Observación |
# | --- | --- |
# | 1.   **año** | esta en formato texto y es una fecha. **nota**(cambiar a fecha) |
# |2.   **mes** |esta en formato entero y es una fecha **nota**(cambiar a fecha)|
# |3.   **fuente Colocación**| ok formato inicial|
# |4.   **Id Tipo Prod**| ok formato inicial|
# |5.   **Tipo Productor**| ok formato inicial|
# |6.  **Valor Inversion**| esta en formato texto y es númerico **nota**(cambiar a número)|
# |7.  **colocación**| esta en formato texto y es númerico **nota**(cambiar a número entero)|
# |8.   **ID Depto**| ok formato inicial|
# |9.   **Departamento Inversion**| ok formato inicial|
# |10.  **Id Munic**| ok formato inicial |
# |11.   **Municipio Inversion**| ok formato inicial|
# |12.  **Municipio de PostConflico?**| ok formato inicial|
# |13.   **depcol**| ok formato inicial|
# |14.   **Departamento de Colocacion de Credito**| ok formato inicial|
# |15.   **muncol**| esta en formato texto y es númerico **nota**(cambiar a número entero)|
# |16.   **Municipio Colocacion de Credito**|  ok formato inicial|
# |17.   **plazo**| ok formato inicial|
# |18.   **Linea de Credito**| ok formato inicial|
# |19.  **Linea de Produccion**| Linea de Produccion|
# |20.   **ID Rubro**| esta en formato texto y es númerico **nota**(cambiar a número entero)|
# |21. **Destino de Credito**| formato correcto (limpiar columna tiene incluido el id del rubro)
# |22. **genero**| ok formato inicial |
# |23. **% FAG**|  ok formato inicial|
# |24. **Vlr Inic Garantia**|  esta en formato texto y es númerico **nota**(cambiar a número entero o decimal (explorar))|
# |25. **latitud**| ok formato inicial |
# |26. **longitud**|  ok formato inicial|
# |27. **cantidad**| ok formato inicial|

# %% [markdown]
# ##**1.3- Revisión de elementos de cada una de las variables**
#
# Se decide revisar por grupos de a 5 el conjunto de variables, por lo cual se asigna una función para la revisión de los elementos.

# %%
#Función para comprobar que elementos hay en la columna

def revisar_columnas(colum_ini,column_final):
  #Se crea una lista con los nombres de cada variable
  review_columns = list(data.columns)
  #se crea ciclo for para recorrer las posiciones de los elementos dentro de la lista delimitadas en el range
  for x in range(colum_ini,column_final):
  #se crea informe print con los elementos de cada variable
    elementos = print(f"La variable {review_columns[x].upper()} cuenta con los siguientes elementos: \n" + f"{data[{review_columns[x]}].value_counts()} \n\n")
  return elementos

# %%
revisar_columnas(0,5)
# Out:
# La variable AÑO cuenta con los siguientes elementos:
# año
# 2,021    479978
# 2,022    370163
# dtype: int64
#
#
# La variable MES cuenta con los siguientes elementos:
# mes
# 8      95808
# 9      82851
# 7      82673
# 3      82669
# 6      81445
# 4      80725
# 2      78928
# 5      73818
# 1      67410
# 10     43274
# 11     41326
# 12     39214
# dtype: int64
#
#
# La variable FUENTE COLOCACION cuenta con los siguientes elementos:
# fuente Colocacion
# REDESCUENTO          603267
# SUSTITUTA            240342
# AGROPECUARIA           6532
# dtype: int64
#
#
# La variable ID TIPO PROD cuenta con los siguientes elementos:
# Id Tipo Prod
# 0               728746
# 1                99052
# 2                22343
# dtype: int64
#
#
# La variable TIPO PRODUCTOR cuenta con los siguientes elementos:
# Tipo Productor
# PEQUEÑO           728746
# MEDIANO            99052
# GRANDE             22343
# dtype: int64

# %%
revisar_columnas(5,10)
# Out:
# La variable VALOR INVERSION cuenta con los siguientes elementos:
# Valor Inversion
# 10,000,000         60804
# 15,000,000         45964
# 12,000,000         32426
# 20,000,000         32084
# 5,000,000          28997
#                    ...
# 2,528,763              1
# 2,529,975              1
# 2,529,984              1
# 2,530,500              1
# 999,998,031            1
# Length: 66656, dtype: int64
#
#
# La variable COLOCACION cuenta con los siguientes elementos:
# colocacion
# 10,000,000     56456
# 15,000,000     42765
# 20,000,000     33366
# 12,000,000     29693
# 5,000,000      27535
#                ...
# 2,648,645          1
# 2,648,568          1
# 2,648,500          1
# 2,648,497          1
# 999,999,984        1
# Length: 114659, dtype: int64
#
#
# La variable ID DEPTO cuenta con los siguientes elementos:
# ID Depto
# 15          87836
# 5           86114
# 25          80527
# 52          74209
# 41          54557
# 68          54403
# 19          50748
# 73          49023
# 76          33696
# 23          30440
# 17          26752
# 50          25237
# 54          24747
# 13          19379
# 85          18075
# 70          16090
# 18          13996
# 86          13472
# 47          13204
# 20          13136
# 66          12594
# 81           9986
# 11           8786
# 44           7248
# 8            6897
# 63           6837
# 27           5310
# 95           3708
# 99           1110
# 97            958
# 94            448
# 88            355
# 91            263
# dtype: int64
#
#
# La variable DEPARTAMENTO INVERSION cuenta con los siguientes elementos:
# Departamento Inversion
# BOYACÁ                                      87836
# ANTIOQUIA                                   86114
# CUNDINAMARCA                                80527
# NARIÑO                                      74209
# HUILA                                       54557
# SANTANDER                                   54403
# CAUCA                                       50748
# TOLIMA                                      49023
# VALLE DEL CAUCA                             33696
# CÓRDOBA                                     30440
# CALDAS                                      26752
# META                                        25237
# NORTE DE SANTANDER                          24747
# BOLÍVAR                                     19379
# CASANARE                                    18075
# SUCRE                                       16090
# CAQUETÁ                                     13996
# PUTUMAYO                                    13472
# MAGDALENA                                   13204
# CESAR                                       13136
# RISARALDA                                   12594
# ARAUCA                                       9986
# BOGOTÁ, D.C.                                 8786
# LA GUAJIRA                                   7248
# ATLÁNTICO                                    6897
# QUINDÍO                                      6837
# CHOCÓ                                        5310
# GUAVIARE                                     3708
# VICHADA                                      1110
# VAUPÉS                                        958
# GUAINÍA                                       448
# SAN ANDRÉS, PROVIDENCIA Y SANTA CATALINA      355
# AMAZONAS                                      263
# dtype: int64
#
#
# La variable ID MUNIC cuenta con los siguientes elementos:
# Id Munic
# 11,001      8786
# 41,551      7536
# 52,356      7006
# 19,698      4856
# 52,835      4282
#             ...
# 91,669         2
# 91,430         2
# 94,885         1
# 97,161         1
# 94,886         1
# Length: 1106, dtype: int64

# %%
revisar_columnas(10,15)
# Out:
# La variable MUNICIPIO INVERSION cuenta con los siguientes elementos:
# Municipio Inversion
# BOGOTÁ, D.C.              8786
# PITALITO                  7536
# IPIALES                   7006
# LA UNIÓN                  6031
# SANTANDER DE QUILICHAO    4856
#                           ...
# SIPÍ                         5
# MAPIRIPANA                   2
# CARURÚ                       1
# CACAHUAL                     1
# LA GUADALUPE                 1
# Length: 1027, dtype: int64
#
#
# La variable MUNICIPIO DE POSTCONFLICO? cuenta con los siguientes elementos:
# Municipio de PostConflico?
# N                             581714
# S                             268427
# dtype: int64
#
#
# La variable DEPCOL cuenta con los siguientes elementos:
# depcol
# 5         91663
# 15        89216
# 25        80666
# 52        74458
# 41        55620
# 68        53226
# 19        49074
# 73        47831
# 76        32725
# 23        28114
# 17        27322
# 54        23901
# 50        22514
# 13        16987
# 70        16527
# 85        16376
# 20        14563
# 18        14270
# 11        14080
# 86        13341
# 47        12522
# 66        12328
# 81         9849
# 8          7335
# 63         7104
# 44         7020
# 27         4368
# 95         3969
# 99         1018
# 97          950
# 94          438
# 91          406
# 88          360
# dtype: int64
#
#
# La variable DEPARTAMENTO DE COLOCACION DE CREDITO cuenta con los siguientes elementos:
# Departamento de Colocacion de Credito
# ANTIOQUIA                                   91663
# BOYACÁ                                      89216
# CUNDINAMARCA                                80666
# NARIÑO                                      74458
# HUILA                                       55620
# SANTANDER                                   53226
# CAUCA                                       49074
# TOLIMA                                      47831
# VALLE DEL CAUCA                             32725
# CÓRDOBA                                     28114
# CALDAS                                      27322
# NORTE DE SANTANDER                          23901
# META                                        22514
# BOLÍVAR                                     16987
# SUCRE                                       16527
# CASANARE                                    16376
# CESAR                                       14563
# CAQUETÁ                                     14270
# BOGOTÁ, D.C.                                14080
# PUTUMAYO                                    13341
# MAGDALENA                                   12522
# RISARALDA                                   12328
# ARAUCA                                       9849
# ATLÁNTICO                                    7335
# QUINDÍO                                      7104
# LA GUAJIRA                                   7020
# CHOCÓ                                        4368
# GUAVIARE                                     3969
# VICHADA                                      1018
# VAUPÉS                                        950
# GUAINÍA                                       438
# AMAZONAS                                      406
# SAN ANDRÉS, PROVIDENCIA Y SANTA CATALINA      360
# dtype: int64
#
#
# La variable MUNCOL cuenta con los siguientes elementos:
# muncol
# 11,001    14080
# 52,001    10359
# 5,001     10322
# 41,551     9368
# 19,001     9325
#           ...
# 5,321         3
# 25,841        3
# 68,296        3
# 44,378        2
# 44,078        1
# Length: 834, dtype: int64

# %%
revisar_columnas(15,20)
# Out:
# La variable MUNICIPIO COLOCACION DE CREDITO cuenta con los siguientes elementos:
# Municipio Colocacion de Credito
# BOGOTÁ, D.C.                       14080
# PASTO                              10359
# MEDELLÍN                           10322
# PITALITO                            9368
# POPAYÁN                             9325
#                                    ...
# TOCAIMA                                3
# GALÁN                                  3
# GUATAPÉ                                3
# HATONUEVO                              2
# BARRANCAS                              1
# Length: 787, dtype: int64
#
#
# La variable PLAZO cuenta con los siguientes elementos:
# plazo
# 36       152343
# 60       102857
# 12        90765
# 72        48615
# 84        47609
#           ...
# 186           1
# 203           1
# 204           1
# 236           1
# 177           1
# Length: 178, dtype: int64
#
#
# La variable LINEA DE CREDITO cuenta con los siguientes elementos:
# Linea de Credito
# Capital de Trabajo          440737
# Inversión                   334883
# Normalización de Cartera     74521
# dtype: int64
#
#
# La variable LINEA DE PRODUCCION cuenta con los siguientes elementos:
# Linea de Produccion
# SOSTENIMIENTO (CT)                 196823
# SIEMBRAS (I)                       168955
# MICROCREDITO (CT)                  155175
# COMPRA DE ANIMALES (I)             139425
# PRODUCCIÓN (CT)                     62933
# INFRAEST Y ADECU DE TIERRAS (I)     38138
# COMERCIALIZACION (CT)               23062
# OTRAS ACTIVIDADES (I)               22534
# SERVICIOS DE APOYO (CT)             13091
# MAQUINARIA Y EQUIPO (I)             12600
# COMERCIALIZACION (I)                 8874
# ACTIVIDADES RURALES (CT)             4049
# SERVICIOS DE APOYO (I)               1903
# TRANSFORMACIÓN (CT)                  1196
# ACTIVIDADES RURALES (I)               740
# CONSOLIDACION DE PASIVOS (N)          641
# TARJETA DE CREDITO (CT)                 2
# dtype: int64
#
#
# La variable ID RUBRO cuenta con los siguientes elementos:
# ID Rubro
# 165,000     155175
# 160,000      99564
# 253,400      80193
# 141,100      50658
# 132,310      33447
#              ...
# 741,150          1
# 151,621          1
# 651,050          1
# 151,761          1
# 920,009          1
# Length: 339, dtype: int64

# %%
revisar_columnas(20,25)
# Out:
# La variable DESTINO DE CREDITO cuenta con los siguientes elementos:
# Destino de Credito
# 165000 CAPITAL DE TRABAJO - MICROCRÉDITO AGROPECUARIO Y RURAL                   155175
# 160000 CAPITAL DE TRABAJO - UNIDAD PRODUCTIVA CAMPESINA                          99564
# 253400 Vientres bovinos y bufalinos comerciales cria y D.P                       67192
# 141100 Café                                                                      44365
# 132310 Sostenimiento café                                                        32972
#                                                                                  ...
# 741150 TRANSPORTE ESPECIALIZADO - NUEVO - SERVICIOS DE APOYO A LA PRODUCCIÓN         1
# 121620 ESTROPAJO - CICLO CORTO - SIEMBRA                                             1
# 121600 PEPINO - CICLO CORTO - SIEMBRA                                                1
# 121390 Repollo                                                                       1
# 920009 REPRODUCCION Y SOSTENIMIENTO PIRARUCU LEC                                     1
# Length: 523, dtype: int64
#
#
# La variable GENERO cuenta con los siguientes elementos:
# genero
# H         500188
# M         313544
# S          36409
# dtype: int64
#
#
# La variable % FAG cuenta con los siguientes elementos:
# % FAG
# 80.0     432880
# 100.0     68800
# 50.0      24601
# 60.0      14951
# 58.0        316
# 40.0        209
# 78.0        208
# 30.0        197
# 20.0        197
# 48.0        130
# 10.0        112
# 75.0        110
# 49.0        101
# 15.0         53
# 25.0         48
# 56.0         47
# 35.0         33
# 70.0         25
# 57.0         25
# 46.0         18
# 1.0          18
# 45.0         17
# 59.0         17
# 5.0          17
# 76.0         16
# 47.0         15
# 55.0         10
# 79.0         10
# 34.0          7
# 65.0          6
# 6.0           5
# 38.0          5
# 22.0          4
# 31.0          4
# 44.0          4
# 8.0           4
# 42.0          3
# 12.0          3
# 68.0          2
# 18.0          2
# 77.0          2
# 14.0          2
# 72.0          2
# 51.0          2
# 54.0          2
# 32.0          2
# 21.0          2
# 23.0          2
# 24.0          2
# 43.0          2
# 37.0          2
# 41.0          2
# 16.0          1
# 11.0          1
# 27.0          1
# 39.0          1
# 7.0           1
# 36.0          1
# 28.0          1
# 92.0          1
# dtype: int64
#
#
# La variable VLR INIC GARANTIA cuenta con los siguientes elementos:
# Vlr Inic Garantia
# 8,000,000            45133
# 12,000,000           38301
# 16,000,000           23754
# 9,600,000            22892
# 4,000,000            21013
#                      ...
# 2,731,834                1
# 2,730,830                1
# 2,730,771                1
# 2,730,513                1
# 999,990                  1
# Length: 38660, dtype: int64
#
#
# La variable LATITUD cuenta con los siguientes elementos:
# latitud
#  5.250000    13899
#  5.750000    13521
#  1.750000    12458
#  5.416667    12144
#  5.583333    10630
#              ...
#  3.012080        2
# -4.150000        2
# -0.622280        2
#  1.364840        1
#  3.514250        1
# Length: 575, dtype: int64

# %%
revisar_columnas(25,27)
# Out:
# La variable LONGITUD cuenta con los siguientes elementos:
# longitud
# -75.916667    17321
# -76.166667    16855
# -75.166667    14957
# -75.666667    14238
# -75.583333    14003
#               ...
# -69.950060        2
# -72.383214        2
# -67.415290        1
# -70.733333        1
# -67.046459        1
# Length: 504, dtype: int64
#
#
# La variable CANTIDAD cuenta con los siguientes elementos:
# cantidad
# 1           850141
# dtype: int64

# %% [markdown]
# ##**1.4- Correción de formatos de variables y limpieza de elementos de variables**
#
# se ejecuta correción de formatos variables y limpieza de elementos.

# %% [markdown]
# ###**1.4.1- Corrección de formatos de variables**

# %%
#Función para convertir a número entero los textos de los ID y año

#entrada: recibe como argumento el nombre de la variable a convertir a entero
#salida: serie de pandas de numeros enteros
def convert_int(variable):
  serie_numerica = data[variable].apply(lambda x: int(x.replace(",","")))
  return serie_numerica

# %%
#función para convertir cantidades expresadas en texto a decimal 

#entrada: recibe como argumento el nombre de la variable a convertir a decimal
#salida: serie de pandas de números decimales
def convert_float(variable):
  serie_decimal = data[variable].apply(lambda x: x if x == None else float(x.replace(",","")))
  return serie_decimal

# %%
#se convierte variable año  a número
data["año"] = convert_int("año")

# %%
# se convierte estas variables a valores númericos para su revisión estadistica
data["Valor Inversion"] = convert_float("Valor Inversion") 
data["colocacion"] = convert_float("colocacion") 
data["Vlr Inic Garantia"] = convert_float("Vlr Inic Garantia")

# %%
#se crea una nueva caracteristica para unir año y mes para creación de serie de tiempo
from  datetime import datetime
from datetime import date


data["fecha"] = data["mes"].astype(str).str.cat(data["año"].astype(str),sep="/")
data["fecha"] = data["fecha"].map(lambda x: datetime.strptime(x,"%m/%Y"))

# %% [markdown]
# ###**1.4.2- Limpieza de columnas**
# Ya con los formatos arreglados, se procede a limpiar las columnas con los detalles, vistos en la fase de revisión.

# %% [markdown]
# ####**1.4.2.1- Cambio en el formato del nombre de cada una de las columnas**

# %%
#se procede en darle formato de minusculas a los nombres de las columnas y se unen las columnas con espacios con un guion bajo.

#se crea lista de los nombre de las columnas
cambio_en_columnas = list(data.columns)

#se crea diccionario vacio para guardar el nombre de la columna como llave y el valor con su nuevo nombre
dic_columnas = dict()

#se itera lista con nombres de columnas, para darle el formato propuesto y cambiar el actual.
for elemento in cambio_en_columnas:
  #como cada nombre puede tener mas de una palabra, se crea una condición para que las columnas
  #que tengan una sola palabra solo se le aplique el cambio a minuscula y las que no adicionalmente
  #se unan sus palabras con un guión bajo.
  if len(elemento.split()) == 1:
    x = elemento.lower().strip()
    dic_columnas[elemento] = x
  else: 
    x = elemento.lower().strip().replace(" ","_")
    dic_columnas[elemento] = x

# %%
#se comprueba resultados
print(dic_columnas)
# Out:
# {'año': 'año', 'mes': 'mes', 'fuente Colocacion': 'fuente_colocacion', 'Id Tipo Prod': 'id_tipo_prod', 'Tipo Productor': 'tipo_productor', 'Valor Inversion': 'valor_inversion', 'colocacion': 'colocacion', 'ID Depto': 'id_depto', 'Departamento Inversion': 'departamento_inversion', 'Id Munic': 'id_munic', 'Municipio Inversion': 'municipio_inversion', 'Municipio de PostConflico?': 'municipio_de_postconflico?', 'depcol': 'depcol', 'Departamento de Colocacion de Credito': 'departamento_de_colocacion_de_credito', 'muncol': 'muncol', 'Municipio Colocacion de Credito': 'municipio_colocacion_de_credito', 'plazo': 'plazo', 'Linea de Credito': 'linea_de_credito', 'Linea de Produccion': 'linea_de_produccion', 'ID Rubro': 'id_rubro', 'Destino de Credito': 'destino_de_credito', 'genero': 'genero', '% FAG': '%_fag', 'Vlr Inic Garantia': 'vlr_inic_garantia', 'latitud': 'latitud', 'longitud': 'longitud', 'cantidad': 'cantidad', 'fecha': 'fecha'}

# %%
#Se remplaza el nombre de las columnas por el cambio propuesto.
data.rename(columns= dic_columnas , inplace=True)

# %%
#se comprueban cambios
data.columns
# Out:
# Index(['año', 'mes', 'fuente_colocacion', 'id_tipo_prod', 'tipo_productor',
#        'valor_inversion', 'colocacion', 'id_depto', 'departamento_inversion',
#        'id_munic', 'municipio_inversion', 'municipio_de_postconflico?',
#        'depcol', 'departamento_de_colocacion_de_credito', 'muncol',
#        'municipio_colocacion_de_credito', 'plazo', 'linea_de_credito',
#        'linea_de_produccion', 'id_rubro', 'destino_de_credito', 'genero',
#        '%_fag', 'vlr_inic_garantia', 'latitud', 'longitud', 'cantidad',
#        'fecha'],
#       dtype='object')

# %% [markdown]
# ####**1.4.2.2- Cambios en el formato de los elementos de cada una de las columnas**

# %%
#Función para normalizar el formato del texto de cada uno de los elementos de las variables tipo objetos
#se cambiara a miniscula y sin acentos
#Función recibe el nombre de una columna y devuelve una columna normalizada.

def format_text_normalize(columna):
  serie_text_normalize = data[columna].str.normalize('NFD').str.encode('ascii', errors='ignore').str.decode('utf-8').str.lower()
  return serie_text_normalize

# %%
#se escogen la columnas tipo objetos para normalizar su texto y crea una lista
columnas_a_normalizar = list(data.select_dtypes(include=['object']).columns)

#Se itera cada elemmento de la lista y se le aplica la función para normalizar texto
for elemento in columnas_a_normalizar:
  data[elemento] = format_text_normalize(elemento)

# %%
#se comprueban cambios
for elemento in columnas_a_normalizar:
  print("+===============================================================================+")
  print(f"""Cada uno de los elementos de la columna {elemento.upper()} son los siguientes:""")
  print("+===============================================================================+")
  print(f"\n\n {data[elemento].unique()}\n\n""")
# Out:
# +===============================================================================+
# Cada uno de los elementos de la columna FUENTE_COLOCACION son los siguientes:
# +===============================================================================+
#
#
#  ['redescuento' 'sustituta' 'agropecuaria']
#
#
# +===============================================================================+
# Cada uno de los elementos de la columna TIPO_PRODUCTOR son los siguientes:
# +===============================================================================+
#
#
#  ['mediano' 'pequeno' 'grande']
#
#
# +===============================================================================+
# Cada uno de los elementos de la columna DEPARTAMENTO_INVERSION son los siguientes:
# +===============================================================================+
#
#
#  ['antioquia' 'santander' 'huila' 'casanare' 'cesar' 'cundinamarca'
#  'cordoba' 'tolima' 'risaralda' 'boyaca' 'caldas' 'bolivar' 'caqueta'
#  'putumayo' 'valle del cauca' 'la guajira' 'narino' 'magdalena'
#  'norte de santander' 'atlantico' 'quindio' 'guaviare' 'sucre' 'cauca'
#  'arauca' 'meta' 'vaupes' 'guainia' 'bogota, d.c.' 'choco' 'amazonas'
#  'vichada' 'san andres, providencia y santa catalina']
#
#
# +===============================================================================+
# Cada uno de los elementos de la columna ID_MUNIC son los siguientes:
# +===============================================================================+
#
#
#  ['5,237' '68,169' '41,807' ... '94,885' '91,669' '97,161']
#
#
# +===============================================================================+
# Cada uno de los elementos de la columna MUNICIPIO_INVERSION son los siguientes:
# +===============================================================================+
#
#
#  ['donmatias' 'charta' 'timana' ... 'certegui' 'la guadalupe' 'caruru']
#
#
# +===============================================================================+
# Cada uno de los elementos de la columna MUNICIPIO_DE_POSTCONFLICO? son los siguientes:
# +===============================================================================+
#
#
#  ['s' 'n']
#
#
# +===============================================================================+
# Cada uno de los elementos de la columna DEPARTAMENTO_DE_COLOCACION_DE_CREDITO son los siguientes:
# +===============================================================================+
#
#
#  ['antioquia' 'santander' 'huila' 'casanare' 'boyaca' 'cesar'
#  'cundinamarca' 'cordoba' 'tolima' 'meta' 'risaralda' 'caldas' 'bolivar'
#  'caqueta' 'putumayo' 'valle del cauca' 'la guajira' 'narino' 'magdalena'
#  'norte de santander' 'atlantico' 'quindio' 'guaviare' 'sucre' 'cauca'
#  'arauca' 'bogota, d.c.' 'vaupes' 'guainia' 'choco' 'amazonas' 'vichada'
#  'san andres, providencia y santa catalina']
#
#
# +===============================================================================+
# Cada uno de los elementos de la columna MUNCOL son los siguientes:
# +===============================================================================+
#
#
#  ['5,237' '68,001' '41,807' '85,139' '15,425' '15,183' '20,614' '25,183'
#  '23,466' '73,563' '41,319' '73,411' '85,400' '50,568' '66,045' '15,814'
#  '17,013' '68,689' '68,432' '20,001' '13,430' '18,753' '25,649' '86,568'
#  '23,162' '76,275' '18,001' '85,010' '44,430' '13,052' '25,307' '86,320'
#  '52,835' '25,843' '47,551' '25,269' '15,759' '44,001' '20,060' '54,518'
#  '44,279' '23,660' '23,189' '8,078' '63,130' '95,001' '68,861' '73,443'
#  '68,575' '70,713' '25,377' '8,638' '66,682' '19,698' '44,847' '5,034'
#  '23,670' '70,215' '15,176' '76,400' '81,794' '20,011' '5,234' '13,468'
#  '15,238' '5,887' '5,579' '73,585' '41,551' '68,679' '18,150' '70,771'
#  '50,313' '76,147' '47,555' '25,875' '76,364' '25,245' '47,288' '52,356'
#  '15,572' '11,001' '25,899' '23,500' '5,440' '17,174' '17,380' '5,250'
#  '5,045' '13,688' '52,838' '44,650' '47,189' '20,517' '25,290' '23,555'
#  '97,001' '47,245' '5,147' '17,614' '5,847' '76,248' '85,250' '41,298'
#  '41,396' '81,001' '19,532' '86,001' '25,320' '86,865' '15,299' '54,498'
#  '23,855' '23,068' '76,895' '70,708' '94,001' '23,417' '54,172' '13,244'
#  '5,154' '5,042' '73,520' '15,469' '63,001' '50,006' '52,399' '73,270'
#  '5,134' '73,168' '5,376' '73,770' '15,667' '15,001' '50,124' '25,438'
#  '41,615' '25,817' '68,235' '23,686' '50,251' '41,872' '68,385' '5,148'
#  '23,678' '68,615' '50,711' '73,678' '68,077' '68,190' '5,400' '15,531'
#  '70,742' '23,001' '5,040' '85,230' '15,755' '17,877' '15,842' '73,854'
#  '17,867' '85,410' '25,530' '70,235' '85,001' '68,296' '5,031' '5,854'
#  '50,001' '50,680' '5,001' '81,736' '50,573' '25,535' '41,797' '63,401'
#  '5,628' '5,038' '27,001' '17,042' '54,003' '5,837' '15,248' '76,001'
#  '25,845' '5,264' '73,504' '76,834' '20,383' '5,360' '41,524' '5,480'
#  '73,555' '41,306' '19,001' '41,001' '17,001' '70,001' '25,386' '41,006'
#  '54,001' '25,286' '52,001' '5,615' '91,001' '41,668' '73,283' '5,756'
#  '25,126' '73,001' '5,209' '85,440' '68,307' '76,520' '68,755' '76,622'
#  '5,197' '5,101' '54,660' '52,019' '73,043' '19,548' '73,686' '15,172'
#  '63,272' '15,087' '5,483' '76,233' '50,223' '15,696' '17,541' '54,743'
#  '23,675' '86,749' '15,686' '25,001' '17,524' '41,548' '66,001' '68,444'
#  '68,211' '19,075' '8,001' '85,263' '15,774' '41,799' '85,162' '5,647'
#  '18,860' '66,088' '68,406' '18,094' '73,624' '70,820' '25,175' '5,088'
#  '76,111' '47,001' '52,287' '25,769' '76,054' '5,129' '25,035' '5,212'
#  '66,170' '23,090' '68,498' '5,282' '68,377' '5,172' '17,513' '15,897'
#  '99,524' '73,449' '41,206' '15,407' '73,067' '76,243' '76,616' '52,227'
#  '41,530' '63,190' '5,425' '15,664' '54,810' '5,364' '50,689' '19,760'
#  '70,823' '41,770' '76,892' '25,740' '5,002' '41,020' '68,895' '54,174'
#  '5,664' '76,736' '15,516' '68,745' '25,658' '25,279' '85,300' '52,693'
#  '73,217' '41,349' '68,162' '68,500' '25,473' '52,250' '68,276' '15,322'
#  '15,494' '19,212' '86,885' '5,308' '54,261' '5,190' '68,547' '50,226'
#  '5,059' '5,642' '68,081' '5,318' '13,001' '73,124' '73,268' '19,100'
#  '25,200' '25,430' '25,873' '63,594' '5,607' '25,214' '25,745' '68,255'
#  '15,599' '5,079' '76,497' '5,353' '25,793' '20,228' '5,761' '73,319'
#  '5,266' '52,683' '52,678' '25,779' '73,055' '19,473' '15,776' '5,674'
#  '19,743' '52,051' '19,450' '15,753' '25,851' '5,690' '25,436' '52,885'
#  '20,013' '25,862' '41,801' '25,797' '73,408' '5,736' '25,662' '18,029'
#  '41,359' '25,328' '15,861' '66,318' '73,236' '76,563' '25,754' '25,736'
#  '68,167' '15,835' '25,402' '15,761' '68,209' '15,646' '73,352' '13,670'
#  '20,710' '25,718' '17,616' '66,400' '17,433' '25,178' '47,058' '5,686'
#  '5,313' '41,132' '5,790' '5,361' '20,295' '20,770' '76,250' '5,093'
#  '23,570' '17,653' '23,182' '50,150' '85,430' '18,460' '85,125' '25,599'
#  '23,580' '25,572' '73,861' '47,707' '47,053' '15,051' '76,823' '76,020'
#  '18,247' '8,137' '47,170' '50,400' '15,507' '20,550' '25,154' '5,576'
#  '18,592' '73,483' '5,792' '73,148' '25,151' '5,051' '54,800' '99,624'
#  '18,756' '13,006' '15,047' '52,317' '50,577' '50,590' '15,377' '15,837'
#  '68,324' '81,220' '15,763' '5,284' '18,785' '68,655' '5,670' '15,367'
#  '86,571' '5,665' '13,744' '18,410' '70,418' '86,757' '54,820' '50,325'
#  '50,683' '15,403' '15,518' '73,152' '15,673' '17,088' '5,490' '85,325'
#  '54,418' '73,461' '25,168' '15,632' '52,215' '25,120' '25,394' '15,816'
#  '15,480' '54,099' '52,786' '27,615' '5,660' '25,326' '52,411' '19,807'
#  '15,244' '41,013' '23,807' '54,480' '76,377' '23,464' '27,800' '54,128'
#  '25,772' '15,296' '73,616' '25,491' '19,355' '5,697' '15,804' '81,065'
#  '41,378' '76,100' '41,026' '50,318' '5,858' '68,229' '5,044' '68,327'
#  '5,495' '15,185' '73,622' '15,455' '25,524' '15,693' '68,147' '73,873'
#  '68,820' '44,855' '52,378' '13,549' '41,518' '54,245' '19,824' '5,658'
#  '41,016' '5,142' '15,537' '63,470' '54,344' '25,777' '15,720' '68,207'
#  '13,140' '15,135' '20,032' '81,591' '68,780' '20,175' '25,799' '63,111'
#  '18,256' '85,225' '68,867' '20,178' '76,122' '52,110' '19,573' '5,604'
#  '68,318' '25,743' '15,514' '52,256' '41,078' '15,097' '70,110' '73,347'
#  '23,672' '15,218' '68,872' '68,079' '25,260' '25,758' '52,036' '52,207'
#  '52,323' '52,260' '25,123' '5,541' '52,612' '15,293' '15,757' '54,313'
#  '13,654' '70,429' '41,885' '76,606' '76,246' '66,687' '5,368' '25,312'
#  '17,486' '66,594' '5,789' '66,440' '41,791' '66,456' '5,895' '5,631'
#  '68,770' '50,350' '19,137' '76,863' '5,380' '17,272' '5,030' '17,050'
#  '19,392' '63,302' '73,026' '76,041' '19,585' '25,513' '41,483' '52,696'
#  '52,687' '5,411' '19,050' '47,318' '19,142' '5,021' '19,809' '19,256'
#  '19,418' '20,621' '19,364' '19,318' '5,315' '20,045' '76,109' '5,125'
#  '5,893' '25,506' '5,543' '52,520' '25,885' '25,426' '17,495' '18,205'
#  '19,693' '52,083' '27,006' '5,310' '5,138' '25,518' '23,079' '99,001'
#  '50,330' '54,720' '25,785' '25,596' '73,671' '25,040' '13,647' '15,542'
#  '70,670' '5,390' '27,205' '20,238' '68,101' '13,473' '8,141' '52,320'
#  '5,036' '68,397' '19,130' '19,780' '13,657' '19,821' '27,075' '41,660'
#  '47,161' '17,665' '70,508' '99,773' '52,210' '66,075' '73,226' '17,446'
#  '15,180' '25,148' '70,717' '52,573' '23,168' '5,809' '76,845' '5,091'
#  '25,181' '25,297' '68,502' '19,110' '73,349' '5,856' '25,878' '23,419'
#  '68,368' '52,540' '76,318' '52,480' '27,245' '25,839' '8,573' '19,517'
#  '73,675' '68,773' '25,053' '20,750' '68,176' '73,024' '70,400' '68,051'
#  '44,560' '68,572' '76,113' '52,352' '15,810' '68,092' '5,649' '54,347'
#  '5,055' '76,828' '41,676' '54,239' '68,468' '25,281' '25,871' '5,667'
#  '52,258' '27,787' '54,377' '68,271' '52,585' '76,869' '76,126' '13,442'
#  '68,464' '50,287' '20,400' '20,443' '25,653' '25,339' '25,407' '41,503'
#  '68,152' '25,398' '15,325' '52,418' '70,124' '27,361' '19,513' '47,660'
#  '5,206' '73,547' '50,686' '54,871' '15,332' '54,125' '17,388' '25,322'
#  '73,870' '25,335' '73,200' '66,383' '41,357' '54,223' '5,819' '50,606'
#  '15,798' '25,372' '25,594' '8,436' '20,787' '19,397' '5,347' '63,690'
#  '68,320' '15,223' '23,574' '25,293' '15,236' '5,150' '68,669' '23,586'
#  '66,572' '5,240' '47,692' '25,823' '19,022' '95,200' '5,585' '68,217'
#  '63,548' '52,233' '54,206' '54,553' '76,130' '63,212' '70,265' '19,455'
#  '8,685' '5,467' '68,179' '5,591' '54,051' '70,678' '41,244' '5,656'
#  '5,145' '17,777' '68,298' '5,679' '8,421' '8,372' '8,606' '88,564'
#  '86,573' '17,442' '68,418' '54,599' '13,673' '68,344' '73,030' '88,001'
#  '76,306' '13,836' '5,861' '8,758' '52,385' '52,079' '25,815' '85,015'
#  '19,290' '25,867' '25,645' '25,841' '44,874' '8,296' '44,078' '68,121'
#  '25,317' '5,659' '13,683' '44,378' '8,433' '52,381' '52,254' '5,321'
#  '20,570' '52,685']
#
#
# +===============================================================================+
# Cada uno de los elementos de la columna MUNICIPIO_COLOCACION_DE_CREDITO son los siguientes:
# +===============================================================================+
#
#
#  ['donmatias' 'bucaramanga' 'timana' 'mani' 'macanal' 'chita' 'rio de oro'
#  'choconta' 'montelibano' 'prado' 'guadalupe' 'libano' 'tamara'
#  'puerto gaitan' 'apia' 'toca' 'aguadas' 'san vicente de chucuri' 'malaga'
#  'valledupar' 'magangue' 'san vicente del caguan' 'san bernardo'
#  'puerto asis' 'cerete' 'florida' 'florencia' 'aguazul' 'maicao' 'arjona'
#  'girardot' 'orito' 'san andres de tumaco' 'villa de san diego de ubate'
#  'pivijay' 'facatativa' 'sogamoso' 'riohacha' 'bosconia' 'pamplona'
#  'fonseca' 'sahagun' 'cienaga de oro' 'baranoa' 'calarca'
#  'san jose del guavia' 'velez' 'san sebastian de mariquita'
#  'puerto wilches' 'san onofre' 'la calera' 'sabanalarga'
#  'santa rosa de cabal' 'santander de quilichao' 'uribia' 'andes'
#  'san andres de sotavento' 'corozal' 'chiquinquira' 'la union' 'tame'
#  'aguachica' 'dabeiba' 'santa cruz de mompox' 'duitama' 'yarumal'
#  'puerto berrio' 'purificacion' 'pitalito' 'san gil'
#  'cartagena del chaira' 'sucre' 'granada' 'cartago' 'plato' 'villeta'
#  'jamundi' 'el colegio' 'fundacion' 'ipiales' 'puerto boyaca'
#  'bogota, d.c.' 'zipaquira' 'monitos' 'marinilla' 'chinchina' 'la dorada'
#  'el bagre' 'apartado' 'santa rosa del sur' 'tuquerres'
#  'san juan del cesar' 'cienaga' 'pailitas' 'fusagasuga' 'planeta rica'
#  'mitu' 'el banco' 'carepa' 'riosucio' 'urrao' 'el cerrito'
#  'paz de ariporo' 'garzon' 'la plata' 'arauca' 'patia' 'mocoa' 'guaduas'
#  'valle del guamuez' 'garagoa' 'ocana' 'valencia' 'ayapel' 'zarzal'
#  'san marcos' 'inirida' 'lorica' 'chinacota' 'el carmen de boliva'
#  'caucasia' 'santa fe de antioquia' 'palocabildo' 'moniquira' 'armenia'
#  'acacias' 'falan' 'campamento' 'chaparral' 'la ceja' 'suarez'
#  'san luis de gaceno' 'tunja' 'cabuyaro' 'medina' 'rivera' 'tocancipa'
#  'el carmen de chucuri' 'san pelayo' 'el castillo' 'villavieja'
#  'landazuri' 'el carmen de viboral' 'san carlos' 'rionegro' 'vistahermosa'
#  'san luis' 'barbosa' 'cimitarra' 'pauna' 'san juan de since' 'monteria'
#  'anori' 'orocue' 'socota' 'viterbo' 'umbita' 'valle de san juan'
#  'victoria' 'tauramena' 'paratebueno' 'galeras' 'yopal' 'galan' 'amalfi'
#  'valdivia' 'villavicencio' 'san carlos de guaroa' 'medellin' 'saravena'
#  'puerto lopez' 'pasca' 'tesalia' 'la tebaida' 'angostura' 'quibdo'
#  'anserma' 'abrego' 'turbo' 'el espino' 'cali' 'une' 'entrerrios' 'ortega'
#  'tulua' 'la gloria' 'itagui' 'palermo' 'mutata' 'planadas' 'gigante'
#  'popayan' 'neiva' 'manizales' 'sincelejo' 'la mesa' 'acevedo'
#  'san jose de cucuta' 'funza' 'pasto' 'leticia' 'san agustin' 'fresno'
#  'sonson' 'cajica' 'ibague' 'concordia' 'villanueva' 'giron' 'palmira'
#  'socorro' 'roldanillo' 'cocorna' 'ciudad bolivar' 'salazar' 'alban'
#  'anzoategui' 'piendamo  tunia' 'santa isabel' 'chinavita' 'filandia'
#  'belen' 'narino' 'dagua' 'cubarral' 'santa sofia' 'pensilvania' 'silos'
#  'san bernardo del viento' 'sibundoy' 'santana' 'agua de dios' 'palestina'
#  'pital' 'pereira' 'matanza' 'contratacion' 'balboa' 'barranquilla' 'pore'
#  'susacon' 'tello' 'monterrey' 'san andres de cuerquia' 'valparaiso'
#  'belen de umbria' 'lebrija' 'belen de los andaquies' 'rovira'
#  'santiago de tolu' 'chia' 'bello' 'guadalajara de buga' 'santa marta'
#  'funes' 'subachoque' 'argelia' 'caldas' 'anapoima' 'copacabana'
#  'dosquebradas' 'canalete' 'ocamonte' 'fredonia' 'la belleza' 'chigorodo'
#  'pacora' 'zetaquira' 'la primavera' 'melgar' 'colombia' 'villa de leyva'
#  'ataco' 'el aguila' 'riofrio' 'cumbal' 'circasia' 'maceo'
#  'san jose de pare' 'tibu' 'jardin' 'san martin' 'sotara paispamba'
#  'san jose de toluviejo' 'suaza' 'yumbo' 'sibate' 'abejorral' 'algeciras'
#  'zapatoca' 'chitaga' 'san pedro de los milagros' 'sevilla' 'paipa'
#  'simacota' 'san francisco' 'fomeque' 'san pablo' 'coyaima' 'hobo'
#  'cerrito' 'oiba' 'mosquera' 'el charco' 'floridablanca' 'guateque'
#  'nuevo colon' 'corinto' 'villagarzon' 'girardota' 'el zulia' 'cisneros'
#  'piedecuesta' 'cumaral' 'salgar' 'barrancabermeja' 'guarne'
#  'cartagena de indias' 'cajamarca' 'espinal' 'bolivar' 'cogua' 'madrid'
#  'villapinzon' 'quimbaya' 'retiro' 'cota' 'simijaca' 'el playon'
#  'ramiriqui' 'obando' 'hispania' 'tausa' 'curumani' 'sopetran' 'guamo'
#  'envigado' 'sandona' 'samaniego' 'susa' 'armero' 'morales' 'sutamarchan'
#  'san vicente ferrer' 'silvia' 'arboleda' 'mercaderes' 'soata' 'utica'
#  'santo domingo' 'manta' 'yacuanquer' 'agustin codazzi' 'vergara' 'teruel'
#  'tena' 'lerida' 'segovia' 'san juan de rioseco' 'albania' 'isnos'
#  'guayabal de siquima' 'ventaquemada' 'guatica' 'dolores' 'pradera'
#  'soacha' 'sesquile' 'charala' 'turmeque' 'la vega' 'somondoco' 'confines'
#  'samaca' 'icononzo' 'san alberto' 'sasaima' 'risaralda' 'la virginia'
#  'manzanares' 'chipaque' 'ariguani' 'santa rosa de osos' 'campoalegre'
#  'taraza' 'ituango' 'gamarra' 'el dovio' 'betulia' 'pueblo nuevo'
#  'salamina' 'chinu' 'castilla la nueva' 'trinidad' 'milan' 'hato corozal'
#  'apulo' 'puerto libertador' 'puerto salgar' 'venadillo' 'santa ana'
#  'aracataca' 'arcabuco' 'toro' 'alcala' 'el doncello' 'campo de la cruz'
#  'chivolo' 'lejanias' 'otanche' 'pelaya' 'carmen de carupa' 'pueblorrico'
#  'puerto rico' 'natagaima' 'tarso' 'carmen de apicala' 'caqueza'
#  'arboletes' 'teorama' 'santa rosalia' 'solano' 'achi' 'aquitania'
#  'guachucal' 'puerto lleras' 'labranzagrande' 'tuta' 'guavata'
#  'cravo norte' 'sotaquira' 'frontino' 'solita' 'sabana de torres'
#  'san roque' 'jenesano' 'puerto guzman' 'san pedro de uraba' 'simiti'
#  'la montanita' 'los palmitos' 'san miguel' 'toledo' 'mapiripan'
#  'san juan de arama' 'la uvita' 'pajarito' 'casabianca' 'san mateo'
#  'belalcazar' 'necocli' 'san luis de palenque' 'lourdes' 'murillo'
#  'chaguani' 'saboya' 'cordoba' 'cabrera' 'la palma' 'togui' 'muzo'
#  'bochalema' 'taminango' 'guatavita' 'linares' 'timbio' 'el cocuy'
#  'agrado' 'tierralta' 'mutiscua' 'la cumbre' 'momil' 'unguia' 'cachira'
#  'suesca' 'gameza' 'rioblanco' 'nocaima' 'inza' 'el santuario' 'tibana'
#  'arauquita' 'la argentina' 'altamira' 'guamal' 'vegachi' 'curiti' 'anza'
#  'guepsa' 'nechi' 'chitaraque' 'roncesvalles' 'miraflores' 'pandi'
#  'santa rosa de viter' 'capitanejo' 'villarrica' 'tona' 'urumita'
#  'la cruz' 'pinillos' 'paicol' 'el carmen' 'totoro'
#  'san jose de la montana' 'aipe' 'caracoli' 'paz de rio' 'montenegro'
#  'hacari' 'supata' 'sativanorte' 'concepcion' 'calamar' 'campohermoso'
#  'astrea' 'puerto rondon' 'surata' 'chimichagua' 'tenjo' 'buenavista'
#  'el paujil' 'nunchia' 'vetas' 'chiriguana' 'caicedonia' 'buesaco'
#  'puerto tejada' 'remedios' 'guaca' 'silvania' 'paez' 'el rosario'
#  'baraya' 'boavita' 'herveo' 'san antero' 'covarachia' 'barichara'
#  'el rosal' 'sopo' 'ancuya' 'consaca' 'gualmatan' 'el tambo' 'cachipay'
#  'penol' 'ricaurte' 'gachantiva' 'socha' 'gramalote' 'san jacinto'
#  'majagual' 'yaguara' 'restrepo' 'el cairo' 'santuario' 'jerico' 'neira'
#  'quinchia' 'tamesis' 'marsella' 'tarqui' 'mistrato' 'zaragoza' 'sabaneta'
#  'suaita' 'la macarena' 'caldono' 'versalles' 'la estrella' 'filadelfia'
#  'amaga' 'aranzazu' 'la sierra' 'genova' 'alvarado' 'ansermanuevo'
#  'purace' 'pacho' 'nataga' 'santa barbara' 'san lorenzo' 'liborina'
#  'caloto' 'alejandria' 'timbiqui' 'lopez de micay' 'la paz' 'jambalo'
#  'guapi' 'becerril' 'buenaventura' 'caicedo' 'yondo' 'venecia' 'peque'
#  'francisco pizarro' 'yacopi' 'macheta' 'norcasia' 'curillo'
#  'san sebastian' 'acandi' 'gomez plata' 'canasgordas' 'paime'
#  'puerto carreno' 'mesetas' 'sardinata' 'tabio' 'quipile' 'saldana'
#  'anolaima' 'san estanislao' 'pesca' 'sampues' 'la pintada' 'condoto'
#  'el copey' 'candelaria' 'guaitarilla' 'angelopolis' 'cajibio'
#  'san juan nepomuceno' 'toribio' 'bahia solano' 'saladoblanco'
#  'cerro de san antonio' 'san jose' 'ovejas' 'cumaribo' 'contadero'
#  'cunday' 'marulanda' 'chiscas' 'caparrapi' 'san pedro' 'puerres' 'chima'
#  'titiribi' 'ulloa' 'betania' 'choachi' 'gacheta' 'onzaga' 'buenos aires'
#  'honda' 'viota' 'los cordobas' 'jesus maria' 'policarpa' 'guacari'
#  'el carmen de atrato' 'ubala' 'puerto colombia' 'san antonio' 'arbelaez'
#  'san diego' 'alpujarra' 'aratoca' 'manaure' 'puente nacional'
#  'bugalagrande' 'iles' 'tipacoque' 'herran' 'trujillo' 'santa maria'
#  'durania' 'molagavita' 'fosca' 'villagomez' 'san rafael'
#  'el tablon de gomez' 'tado' 'labateca' 'florian' 'pupiales' 'vijes'
#  'calima' 'maria la baja' 'mogotes' 'fuente de oro' 'la jagua de ibirico'
#  'manaure balcon del cesar' 'san cayetano' 'gutierrez' 'lenguazaque'
#  'oporapa' 'carcasi' 'la pena' 'guayata' 'los andes' 'caimito' 'istmina'
#  'padilla' 'sabanas de san angel' 'piedras' 'san juanito' 'villa caro'
#  'guican de la sierra' 'cacota' 'la merced' 'guasca' 'villahermosa'
#  'guayabetal' 'coello' 'la celia' 'iquira' 'cucutilla' 'tenza' 'junin'
#  'quetame' 'manati' 'tamalameque' 'heliconia' 'salento' 'cubara'
#  'puerto escondido' 'gachala' 'chivor' 'carolina' 'san andres'
#  'purisima de la concepcion' 'pueblo rico' 'ebejico'
#  'san sebastian de buenavista' 'topaipi' 'almaguer' 'puerto nare'
#  'coromoro' 'pijao' 'cumbitara' 'convencion' 'puerto santander' 'guaranda'
#  'miranda' 'santo tomas' 'montebello' 'chipata' 'puerto triunfo'
#  'arboledas' 'san benito abad' 'elias' 'san jeronimo' 'caramanta' 'supia'
#  'gambita' 'luruaco' 'juan de acosta' 'repelon' 'providencia'
#  'puerto leguizamo' 'marmato' 'los santos' 'ragonvalia' 'santa catalina'
#  'hato' 'ambalema' 'ginebra' 'turbaco' 'soledad' 'la llanada' 'barbacoas'
#  'tocaima' 'piendamo - tunia' 'el carmen de bolivar'
#  'san jose del guaviare' 'chameza' 'santa rosa de viterbo'
#  'san luis de since' 'viani' 'san antonio del tequendama' 'ubaque'
#  'galapa' 'barrancas' 'guacheta' 'san juan de uraba' 'santa rosa'
#  'hatonuevo' 'malambo' 'la florida' 'el penol' 'guatape' 'pueblo bello']
#
#
# +===============================================================================+
# Cada uno de los elementos de la columna LINEA_DE_CREDITO son los siguientes:
# +===============================================================================+
#
#
#  ['inversion' 'capital de trabajo' 'normalizacion de cartera']
#
#
# +===============================================================================+
# Cada uno de los elementos de la columna LINEA_DE_PRODUCCION son los siguientes:
# +===============================================================================+
#
#
#  ['compra de animales (i)' 'siembras (i)' 'infraest y adecu de tierras (i)'
#  'produccion (ct)' 'comercializacion (i)' 'sostenimiento (ct)'
#  'microcredito (ct)' 'comercializacion (ct)' 'servicios de apoyo (ct)'
#  'maquinaria y equipo (i)' 'otras actividades (i)'
#  'servicios de apoyo (i)' 'actividades rurales (ct)'
#  'consolidacion de pasivos (n)' 'actividades rurales (i)'
#  'tarjeta de credito (ct)' 'transformacion (ct)']
#
#
# +===============================================================================+
# Cada uno de los elementos de la columna ID_RUBRO son los siguientes:
# +===============================================================================+
#
#
#  ['253,061' '151,310' '347,050' '151,050' '141,060' '141,100' '121,510'
#  '121,580' '111,150' '151,340' '641,050' '132,310' '111,500' '141,430'
#  '165,000' '151,051' '182,000' '307,015' '133,010' '408,008' '237,280'
#  '206,013' '160,000' '151,620' '105,001' '347,490' '131,400' '241,150'
#  '141,600' '408,010' '347,485' '121,150' '185,000' '347,300' '206,012'
#  '141,700' '841,050' '151,160' '841,100' '188,000' '632,250' '641,160'
#  '132,200' '129,978' '741,050' '237,050' '547,050' '900,005' '641,150'
#  '611,200' '841,170' '141,101' '151,150' '151,300' '741,300' '910,009'
#  '141,061' '741,060' '151,250' '347,160' '611,950' '611,951' '141,280'
#  '447,600' '347,495' '447,250' '307,014' '732,250' '641,250' '347,480'
#  '206,011' '408,009' '447,100' '900,002' '347,400' '151,640' '632,260'
#  '141,525' '641,200' '741,260' '253,050' '237,300' '447,050' '307,010'
#  '920,000' '641,260' '900,006' '347,100' '732,260' '347,350' '151,020'
#  '151,370' '547,450' '547,420' '307,017' '641,100' '547,410' '447,350'
#  '234,050' '151,410' '151,390' '234,100' '151,700' '347,080' '900,001'
#  '447,200' '447,150' '235,050' '132,420' '132,150' '910,012' '237,350'
#  '632,310' '547,400' '111,350' '651,050' '237,060' '347,200' '632,301'
#  '741,250' '253,400' '253,100' '151,360' '241,160' '650,000' '105,002'
#  '651,000' '741,100' '111,200' '206,003' '121,450' '132,050' '253,000'
#  '131,200' '132,040' '132,220' '141,090' '547,500' '245,100' '741,160'
#  '152,000' '253,450' '121,180' '132,060' '245,150' '151,380' '141,450'
#  '151,130' '151,800' '151,350' '151,650' '151,100' '141,550' '253,750'
#  '141,420' '151,120' '245,200' '647,400' '181,000' '130,003' '244,100'
#  '447,500' '141,150' '141,300' '111,600' '234,230' '121,270' '121,880'
#  '134,010' '144,000' '245,280' '132,270' '111,100' '131,050' '121,630'
#  '320,000' '132,600' '151,750' '245,050' '237,400' '151,610' '253,700'
#  '241,290' '121,570' '121,030' '547,020' '841,300' '151,200' '447,650'
#  '132,300' '132,500' '235,100' '347,070' '632,300' '131,100' '131,250'
#  '151,600' '121,300' '547,460' '151,371' '141,421' '151,381' '180,000'
#  '151,161' '151,131' '141,431' '151,330' '184,000' '347,210' '111,050'
#  '121,090' '133,060' '121,480' '131,150' '131,500' '547,430' '151,052'
#  '447,510' '151,630' '910,010' '253,405' '151,701' '151,251' '920,004'
#  '307,016' '611,150' '547,060' '151,950' '206,014' '111,400' '547,080'
#  '910,001' '151,910' '547,030' '121,330' '151,761' '234,220' '253,105'
#  '253,500' '260,000' '241,350' '159,090' '611,700' '121,690' '253,062'
#  '132,250' '547,250' '347,410' '111,450' '347,499' '611,952' '130,001'
#  '110,000' '121,420' '900,004' '241,291' '920,006' '121,610' '547,070'
#  '151,930' '133,090' '124,000' '920,008' '133,030' '151,550' '121,700'
#  '142,000' '647,410' '151,641' '141,301' '141,601' '111,300' '121,060'
#  '151,400' '141,091' '101,003' '133,080' '101,002' '151,850' '141,110'
#  '151,403' '910,011' '920,005' '347,498' '134,020' '111,250' '900,007'
#  '151,920' '121,680' '132,100' '910,004' '910,002' '910,003' '121,600'
#  '133,070' '151,621' '611,953' '186,000' '111,550' '105,039' '151,320'
#  '131,110' '611,600' '111,800' '741,150' '547,440' '841,250' '347,360'
#  '151,341' '347,497' '447,300' '141,551' '741,110' '237,290' '141,422'
#  '104,003' '141,281' '190,000' '141,130' '307,028' '206,015' '408,011'
#  '408,013' '408,012' '109,002' '102,002' '111,650' '841,200' '101,056'
#  '151,940' '121,620' '105,003' '920,001' '191,000' '108,002' '109,001'
#  '102,001' '920,009' '121,390']
#
#
# +===============================================================================+
# Cada uno de los elementos de la columna DESTINO_DE_CREDITO son los siguientes:
# +===============================================================================+
#
#
#  ['253061 retencion de vientres ganado bovino' '151310 aguacate'
#  '347050 construccion beneficiaderos de cafe' '151050 cacao'
#  '141060 cana panelera' '141100 cafe' '121510 fresas' '121580 sandia'
#  '111150 arroz riego' '151340 citricos' '641050 maquinaria y equipos'
#  '132310 sostenimiento cafe' '111500 papa' '141430 platano'
#  '165000 capital de trabajo - microcredito agropecuario y rural'
#  '141060 cana panelera - siembra' '151051 renovacion cacao'
#  '182000 maiz amarillo'
#  '307015 costos operativos y de funcionamiento para la comercializacion'
#  '133010 platano - sostenimiento'
#  '408008 costos operativos y de funcionamiento para los prestadores de servicios de apoyo para prod'
#  '237280 sostenimiento ceba bovina'
#  '206013 reparacion de infraestructura y de maquinaria para la transformacion'
#  '160000 capital de trabajo - unidad productiva campesina' '151620 uchuva'
#  '105001 equipos y sistemas nuevos para riego y drenaje'
#  '347490 construccion infraestructura para la produccion pecuaria'
#  '131400 otros cultivos perennes - sostenimiento'
#  '241150 pastos  y forrajes' '141600 flores'
#  '408010 costos operativos y de funcionamiento para los prestadores de servicios de apoyo para comer'
#  '347485 reparacion infraestructura agricola' '121150 cebolla cabezona'
#  '185000 maiz blanco' '347300 electrificacion'
#  '206012 costos operativos y de funcionamiento para la transformacion'
#  '141700 cultivos, mantenimiento etapa improductiva (perennes)'
#  '841050 construccion vivienda campesina'
#  '151160 cultivos de silvopastoreo'
#  '841100 reparacion de vivienda campesina' '188000 compra de cartera'
#  '132310 cafe tecnificado - sostenimiento' '141430 platano - siembra'
#  '632250 costo promedio adquisiciones, cartera, inventarios y costos directos para la trasformacion primaria o comercializacion'
#  '151310 aguacate - siembra'
#  '641160 compra de transporte no especializado nuevo'
#  '132200 sostenimiento cana panelera'
#  '129978 capital de trabajo agropecuario y rural'
#  '741050 maquinaria y equipos produccion insumos'
#  '347490 infraestructura - construccion - produccion pecuaria'
#  '237050 sostenimiento de bovinos cria y doble proposito'
#  '547050 equipos y sistemas de riego - nuevo'
#  '900005 turismo rural capital de trabajo'
#  '641150 compra de transporte especializado' '151050 cacao - siembra'
#  '611200 consolidacion de pasivos'
#  '841170 tierra uso agropecuario - compra' '141101 cafe - renovacion'
#  '151150 bosques - siembra' '151300 caucho - siembra'
#  '641160 transporte no especializado - compra - transformacion primaria o comercializacion'
#  '741300 construccion, compra de infraestructuras para servicios de apoyo'
#  '910009 infraestructura, maquinaria y equipos para turismo rural'
#  '141100 cafe - siembra' '141061 cana panelera - renovacion'
#  '151340 citricos - siembra'
#  '141700 cultivos - mantenimiento etapa improductiva - perennes'
#  '347050 beneficiadero de cafe - construccion'
#  '741060 compra de maquinaria y equipos nuevos o usados para servicios de apoyo'
#  '151250 palma - de aceite - siembra' '347160 campamentos - reparacion'
#  '611950 reestructuracion 1%' '611951 reestructuracion 2%'
#  '141280 pina - siembra' '447600 equipo y maquinaria usada' '141280 pina'
#  '347495 reparacion infraestructura pecuaria - produccion pecuaria - reparacion'
#  '641050 maquinaria y equipos - nuevo - transformacion primaria y comercializacion'
#  '447250 equipos nuevos para produccion pecuaria'
#  '307014 construccion y compra de infraestructura para la comercializacion'
#  '732250 costos operativos y de funcionamiento proyectados.'
#  '641250 construccion y compra de infraestructura para la trasformacion primaria o comercializacion'
#  '632250 cartera. inventarios y costos directos - transformacion primaria o comercializacion'
#  '347480 construccion infraestructura agricola'
#  '206011 construccion y compra de infraestructura para la transformacion'
#  '408009 costos operativos y de funcionamiento para los prestadores de servicios de apoyo para trans'
#  '447100 combinadas nuevas'
#  '900002 capital de trabajo - artesanias - comercializacion'
#  '347400 bodegas' '151640 granadilla - perennes - siembra'
#  '632260 costo promedio compras - transformacion primaria o comercializacion'
#  '141525 renovacion cafe por zoca'
#  '841170 compra de tierra para uso agropecuario'
#  '641200 reparacion de maquinaria y equipos'
#  '741260 reparacion de infraestructuras para servicios de apoyo'
#  '253050 retencion vientres bovinos leche y bufalos'
#  '237300 sostenimiento de porcinos'
#  '347495 reparacion infraestructura pecuaria' '447050 tractores nuevos'
#  '307010 comercializacion de ganado'
#  '920000 fuentes de energia no convencionales renovables'
#  '641260 infraestructura - reparacion - transformacion primaria o comercializacion'
#  '900006 extraccion y comercializacion minera capital de trabajo'
#  '347100 construccion campamentos'
#  '732260 costos operativos y de funcionamiento proyectados - servicios de apoyo a la produccion'
#  '347350 construccion carreteables y puentes'
#  '641250 infraestructura - construccion, adquisicion - transformacion primaria o comercializacion'
#  '151020 maranon' '151370 maracuya - siembra'
#  '841100 vivienda campesina - diferente a vis - reparacion'
#  '547450 obras civiles para drenaje - construccion'
#  '547420 reparacion obras civiles manejo recurso hidrico en proyectos pecuarios. acuicolas y pesca'
#  '307017 reparacion de infraestructura y de maquinaria para la comercializacion'
#  '111500 papa - siembra' '347480 invernaderos agricolas - construccion'
#  '641100 unidades y redes de frio'
#  '547410 construccion obras civiles para suministro de agua -           produccion pecuaria o acuicola'
#  '447350 equipos nuevos para acuicultura y pesca'
#  '234050 avicultura - engorde' '234050 avicultura engorde'
#  '151410 palma de chontaduro' '151390 papaya'
#  '547410 obras civiles para suministro de agua - construccion - produccion pecuaria o acuicola'
#  '732250 cartera. inventarios y costos directos - servicios de apoyo a la produccion'
#  '234100 avicultura huevos' '151700 mango'
#  '347080 trapiches paneleros - construccion'
#  '141101 renovacion cafe por siembra'
#  '900001 produccion y comercializacion de artesanias'
#  '447200 implementos y equipos nuevos para la produccion agricola'
#  '447150 maquinaria pesada nueva para uso agropecuario.'
#  '235050 porcinos ceba' '132420 frutales perennes  sostenimiento'
#  '132150 sostenimiento palma de aceite'
#  '910012 infraestructura, maquinaria y equipos para mineria'
#  '237350 sostenimiento acuicultura engorde'
#  '632310 comercializacion de ganado para la transformacion primaria o comercializacion'
#  '547400 construccion obras civiles para riego' '111350 frijol'
#  '651050 prog. informatica - compra - transformacion y/o comercializacion'
#  '237060 sostenimiento bovinos leche y bufalinos'
#  '347200 construccion infraestructura pesquera y acuicola para la produccion pecuaria'
#  '632301 factoring agropecuario'
#  '741250 infraestructura - construccion, adquisicion - servicios de apoyo a la produccion'
#  '253400 vientres bovinos y bufalinos comerciales cria y d.p'
#  '253100 vientres bovinos comerciales leche' '151360 lulo - siembra'
#  '151360 lulo' '241160 compra de porcinos puros'
#  '650000 maquinaria y equipos usados'
#  '105002 adecuacion de tierras para uso agropecuario'
#  '651000 compra de equipos y programas informaticos' '741100 redes frio'
#  '111200 arroz secano'
#  '206003 construccion y compra de infraestructura para forestales para la transformacion'
#  '121450 tomate' '234100 avicultura - huevos'
#  '132050 sostenimiento de cacao'
#  '253000 retencion vientres bovinos cria y d.p'
#  '253100 bovino - comercial - compra - hembra' '131200 yuca - siembra'
#  '132040 sostenimiento de banano' '132220 sostenimiento cana de azucar'
#  '141090 cana de azucar'
#  '547500 construccion obras civiles control de inundaciones'
#  '910009 infraestructura - turismo rural' '245100 cria de porcinos'
#  '253000 bovino - retencion vientres'
#  '253400 vientres bovinos comreciales cria y d. p. - comercial - compra - hembra'
#  '151250 palma de aceite'
#  '741160 transporte no especializado - nuevo - servicios de apoyo a la produccion'
#  '641100 unidades y redes de frio - nuevo - transformacion primaria'
#  '152000 aguacate hass' '132220 cana de azucar - sostenimiento'
#  '253450 bovinos y bufalinos machos'
#  '741050 maquinaria y equipos - nuevo - servicios de apoyo a la produccion'
#  '121180 cebolla de hoja - ciclo corto - siembra'
#  '151051 cacao - renovacion'
#  '347350 carreteables y puentes - construccion'
#  '132060 sostenimiento caucho' '132150 palma - sostenimiento'
#  '245100 porcino - compra - cria'
#  '547400 obras civiles para riego - construccion'
#  '245150 ovinos y caprinos - compra' '151380 mora' '141450 fique'
#  '151130 pero - perennes - siembra'
#  '151800 otros cultivos tardio rendimiento' '151350 curuba'
#  '151650 guanabana - siembra' '151100 ciruelo' '141550 tomate de arbol'
#  '141525 cafe por zoca - renovacion'
#  '253750 retencion de vientres de ganado bovino y bufalino - retencion vientres'
#  '141420 banano' '151120 durazno' '151380 mora - siembra'
#  '151640 granadilla' '245200 animal de labor - compra'
#  '151800 otros cultivos - perennes - siembra'
#  '647400 bodegas manejo post-cosecha' '245200 compra animales de labor'
#  '181000 maiz - amarillo tradicional - clima frio y medio - siembra'
#  '130003 guayaba' '253050 bufalino - retencion vientres'
#  '141550 tomate de arbol - perennes - siembra' '141420 banano - siembra'
#  '151410 palma - de chontaduro - siembra - siembra'
#  '244100 avicultura - reproduccion' '151300 caucho'
#  '132420 frutales - perennes - sostenimiento'
#  '447500 reparacion de maquinaria y embarcaciones - usado'
#  '141150 cafetales envejecidos - renovacion' '141300 vid' '111600 soya'
#  '245150 compra ovinos y caprinos'
#  '234230 sostenimiento especies menores y zoocria'
#  '111150 arroz - siembra' '121270 haba'
#  '121880 plantas medicinales y ornamentales'
#  '237280 bovino - sostenimiento' '134010 pimenton'
#  '121150 cebolla cabezona - ciclo corto - siembra' '151150 bosques'
#  '144000 otros cultivos mediano rendimiento'
#  '245280 reproduccion para acuicultura y camaronicultura' '132270 viveros'
#  '131200 yuca' '111100 algodon' '121180 cebolla de hoja'
#  '131050 arracacha' '121630 otros cultivos'
#  '320000 adquisicion de insumos' '132600 sostenimiento pastos y forrajes'
#  '151750 manzano - siembra' '241150 pastos - siembra'
#  '741250 infraestructura de produccion e insumos'
#  '447350 equipos para acuicultura y pesca'
#  '141150 renovacion cafetales envejecidos'
#  '141600 flores - ciclo largo - siembra'
#  '245050 apicultura, especies menores y zoocria'
#  '237400 sostenimiento pesca' '111200 arroz secano - siembra'
#  '900001 capital de trabajo - artesanias - produccion'
#  '151610 lima tahiti'
#  '447250 maquinaria - nuevo - produccion pecuaria o acuicola'
#  '151610 lima - siembra - tahiti' '253700 equinos asnales y mulares'
#  '447050 tractores - compra' '241290 pitahaya - siembra'
#  '151700 mango - siembra' '121570 melon' '151650 guanabana'
#  '121570 melon - ciclo corto - siembra' '244100 avicultura' '121030 aji'
#  '151390 papaya - siembra'
#  '144000 otros cultivos mediano rendimiento - perennes - siembra'
#  '111350 frijol - siembra'
#  '447200 maquinaria - nuevo - produccion agricola'
#  '121510 fresas - siembra' '151120 durazno - siembra'
#  '547020 adecuacion de tierras para cultivos - altillanura de la orinoquia'
#  '447600 maquinaria - usado'
#  '841300 certificaciones de buenas practicas, de origen, iso, normas nacionales o internacionales'
#  '151200 palma - de coco - siembra' '132200 cana panelera - sostenimiento'
#  '151200 palma de coco'
#  '650000 maquinaria - transformacion primaria o comercializacion - usado'
#  '151350 curuba - perennes - siembra' '447650 equipos - usado'
#  '131050 arracacha - ciclo corto - siembra'
#  '132300 cafe tradicional - sostenimiento'
#  '132500 recuperacion areas cacaoteras - sostenimiento'
#  '347485 invernaderos agricolas - reparacion'
#  '632310 comercializacion de ganado - transformacion primaria o comercializacion'
#  '151620 uchuva - perennes - siembra' '235100 compra conejos y curies'
#  '347070 beneficiadero de cafe - reparacion'
#  '182000  maiz  - amarillo tecnificado'
#  '632300 anticipo a productores - transformacion primaria o comercializacion'
#  '131100 name - siembra' '131250 achira - siembra' '151600 macadamia'
#  '121450 tomate - siembra' '121300 habichuela' '151750 manzano'
#  '547460 obras civiles para drenaje - reparacion'
#  '151371 maracuya - renovacion' '141421 de banano - renovacion'
#  '151381 mora - renovacion' '141450 fique - siembra'
#  '141300 vid - siembra'
#  '180000 maiz  - amarillo tradicional - clima calido y medio - siembra'
#  '151161 mejoramiento de praderas' '151131 pero - perennes - renovacion'
#  '237350 acuicultura y camaronicultura' '132050 cacao - sostenimiento'
#  '141431 platano - renovacion' '151100 ciruelo - siembra'
#  '134010 pimenton      - siembra' '347100 campamentos - construccion'
#  '151330 otros frutales - perennes - siembra'
#  '184000 maiz  blanco tradicional clima calido - blanco tradicional - clima calido - siembra'
#  '130003 guayaba - siembra' '141090 cana de azucar - siembra'
#  '241290 pitahaya' '151370 maracuya'
#  '547450 construccion obras civiles para drenaje'
#  '347210 reparacion infraestructura pesquera y acuicola' '131100 name'
#  '131250 achira' '111050 ajonjoli' '121090 arveja' '133060 ahuyama'
#  '132060 caucho - sostenimiento'
#  '121480 zanahoria - ciclo corto - siembra'
#  '235050 porcino - sostenimiento' '131150 malanga o yautia'
#  '235100 conejos y curies - compra'
#  '131500 otros cultivos tardio rendimiento - perennes - sostenimiento'
#  '547430 reparacion obras civiles para riego, drenaje y control de inundaciones'
#  '151052 renovacion cultivos envejecidos de cacao'
#  '447500 reparacion de maquinaria y embarcaciones'
#  '447510 otros equipos de apoyo nuevos para la actividad agropecuaria'
#  '151630 gulupa' '910010 equipos - turismo rural'
#  '741260 infraestructura - reparacion - servicios de apoyo a la produccion'
#  '141421 renovacion de banano' '151330 otros frutales perennes'
#  '253405 vientres bovinos puros cria y d. p.'
#  '253061 retencion de vientres ganado bovino - retencion vientres'
#  '151701 mango - renovacion' '151251 palma - de aceite - renovacion'
#  '920004 reproduccion y sostenimiento tilapia lec'
#  '307016 anticipo a productores por parte de los comercializadores'
#  '611150 capitalizacion y creacion de empresas'
#  '547060 equipos e implementos para suministro de aguas - nuevo - produccion pecuaria o acuicola'
#  '641260 reparacion infraestructura y maquinaria para la transformacion y/o comercializacion'
#  '641150 transporte especializado - compra - transformacion primaria o comercializacion'
#  '151950 arandano'
#  '206014 anticipo a productores por parte de los transformadores'
#  '237050 bovinos cria y doble proposito - sostenimiento'
#  '111400 maiz - amarillo tradicional - clima calido y medio - siembra'
#  '547080 equipos y sistemas usados para riego y drenaje'
#  '253450 bovino - comercial - compra - macho'
#  '841050 vivienda campesina - construccion - diferente a vis'
#  '547050 equipos y sistemas nuevos para riego y drenaje'
#  '910001 infraestructura, maquinaria y equipos para la produccion de artesanias'
#  '347080 construccion trapiches paneleros' '151910 cholupa'
#  '547030 adecuacion de tierras para cultivos - otras regiones'
#  '185000 maiz  - blanco tradicional - clima frio y medio - siembra'
#  '121480 zanahoria' '121030 aji - ciclo corto - siembra'
#  '547060 equipos e implementos nuevos manejo recurso hidrico en proyectos pecuarios, acuicolas y pesca'
#  '151052 cacao - renovacion cultivos envejecidos'
#  '632300 anticipo a productores para la transformacion primaria o comercializacion'
#  '151630 gulupa - perennes - siembra'
#  '121630 otros cultivos - ciclo corto - siembra'
#  '447150 maquinaria pesada de uso agropecuario - nuevo'
#  '447100 combinadas - nuevo' '121330 lechuga'
#  '151761 morera - perennes - renovacion'
#  '741060 maquinaria y equipos - servicios de apoyo a la produccion - usado'
#  '234220 codornices - huevos' '253105 vientres bovinos puros leche'
#  '253500 vientres bufalos - compra'
#  '347200 infraestructura pesquera y acuicola - construccion - produccion pecuaria'
#  '151160 cultivos de silvopastoreo - siembra'
#  '547080 equipos y sistemas de riego - usado' '260000 biotecnologica'
#  '241350 pastos semilla - siembra' '159090 tarjeta agropecuaria'
#  '611700 pago pasivos financieros' '121690 tabaco - rubio - siembra'
#  '253062 retencion de vientres ganado bufalino'
#  '132250 sostenimiento forestales' '151910 cholupa    - siembra'
#  '547500 obras civiles control de inundaciones - construccion'
#  '447510 otros equipos de apoyo a la actividad agropecuaria - nuevo'
#  '547250 adecuacion tierras para actividad pesquera y acuicola - otras regiones'
#  '347410 bodegas - reparacion - transformacion primaria o comercializacion'
#  '651000 maquinas y equipos informatica - compra'
#  '741160 compra de transporte no especializado nuevo'
#  '245050 apicultura - compra' '910012 equipos - extraccion - mineria'
#  '900006 capital de trabajo - extraccion - mineria'
#  '237300 porcino - cria - sostenimiento' '111450 mani - siembra'
#  '347499 infraestructura transformacion c. siembra - construccion'
#  '611952 reestructuracion 3%' '130001 brevo - siembra'
#  '110000 produccion semillas cultivos c. c.' '121420 remolacha'
#  '900004 comercializacion de metales y piedras preciosas'
#  '241291 pitahaya - renovacion'
#  '920006 reproduccion y sostenimiento cachama lec' '121610 champinones'
#  '547070 equipos usados o reparacion de equipos manejo recurso hidrico en proyectos pecuarios,'
#  '151930 papayuela' '133090 calabaza' '124000 aji tabasco'
#  '910001 infraestructura  produccion  de artesanias - artesanias - produccion'
#  '920008 reproduccion y sost especies nativas lec'
#  '900005 capital de trabajo - turismo rural'
#  '133030 flores - ciclo largo - sostenimiento' '151130 pero'
#  '641200 reparacion maquinaria y equipos - transformacion primaria o comercializacion - usado'
#  '151550 feijoa - siembra' '121700 flores - ciclo corto - siembra'
#  '142000 cardamomo'
#  '647410 bodegas manejo post/cosecha - reparacion - transformacion primaria o comercializacion'
#  '151641 granadilla - perennes - renovacion' '141301 vid - renovacion'
#  '141601 flores tropicales - ciclo largo - renovacion'
#  '547430 obras civiles para suministro de agua - produccion agricola - reparacion'
#  '130001 brevo' '234220 codornices huevos' '151550 feijoa'
#  '121690 tabaco rubio'
#  '253700 equinos, asnales y mulares reproductores machos y hembras.'
#  '131400 otros cultivos mr - perennes - sostenimiento'
#  '547070 "equipos usados o reparacion de equipos manejo recurso hidrico en proyectos pecuarios, acuicolas y de pesca"'
#  '111300 cebada' '121060 ajo' '151400 esparragos'
#  '141091 cana de azucar - renovacion'
#  '101003 maiz amarillo tecnificado clima calido' '133080 brocoli'
#  '253105 vientres bovinos puros leche - compra - hembra - puro'
#  '101002 maiz blanco tecnificado de clima calido'
#  '131150 malanga o yautia - ciclo corto - siembra'
#  '151850 flores tropicales - ciclo largo - siembra'
#  '141110 cafes especiales - siembra' '132040 banano - sostenimiento'
#  '151600 macadamia - siembra'
#  '151403 renovacion cultivos perennes por afectacion fitosanitaria'
#  '910011 infraestructura - extraccion - mineria'
#  '920005 reproduccion y sostenimiento trucha lec'
#  '347498 bodegas  - construccion' '134020 quinua'
#  '121090 arveja - siembra' '111250 avena'
#  '347210 reparacion infraestructura pesquera y acuicola - produccion pecuaria - reparacion'
#  '134020 quinua   - siembra' '111100 algodon - siembra'
#  '121580 sandia - ciclo corto - siembra'
#  '900007 capital de trabajo - comercializacion - mineria'
#  '151403 cultivos - perennes - renovacion por afectacion fitosanitaria'
#  '151920 guatila  - siembra' '121680 tabaco negro'
#  '132100 coco - perennes - sostenimiento'
#  '910004 equipos para comercializacion artesanias'
#  '910002 equipos - artesanias - produccion'
#  '253405 bovino - compra - hembra - puro'
#  '910003 infraestructura - artesanias - comercializacion'
#  '245280 acuicultura' '320000 insumos - compra' '121600 pepino'
#  '133070 apio' '121330 lechuga - ciclo corto - siembra'
#  '151621 uchuva - perennes - renovacion'
#  '121300 habichuela - ciclo corto - siembra' '611953 reestructuracion 4%'
#  '186000 maiz blanco tecnificado clima calido - blanco tecnificado - clima calido - siembra'
#  '133060 ahuyama  - siembra' '111550 sorgo'
#  '105039 adecuaciones locativas y medidas de bioseguridad para la prevencion del covid - 19'
#  '151320 badea' '151251 renovacion palma de aceite'
#  '131110 plantas ornamentales - siembra'
#  '611600 pago pasivos no financieros'
#  '111800 material vegetal - ciclo corto - siembra'
#  '741150 transporte especializado - nuevo - servicios de apoyo a la produccion'
#  '547440 correccion quimica de suelos' '841250 asistencia tecnica'
#  '347360 carreteables y puentes - reparacion'
#  '151341 citricos - renovacion'
#  '547420 obras civiles para suministro de agua - produccion pecuaria o acuicola - reparacion'
#  '347497 infraesructura agricola c. siembra - construccion'
#  '447300 equipos forestales nuevos para la produccion agricola'
#  '237060 bovinos leche y bufalinos - sostenimiento'
#  '141551 tomate de arbol - perennes - renovacion'
#  '151400 esparragos - siembra' '151950 arandano  - siembra'
#  '741110 reparacion redes de frio'
#  '237290 sostenimiento de equinos, asnales y mulares'
#  '141422 banano exportadores - siembra' '151920 guatila'
#  '104003 apicultura' '141281 pina - renovacion'
#  '121880 plantas medicinales - siembra'
#  '129978 capital de trabajo agropecuario rural'
#  '151930 papayuela  - siembra'
#  '190000 gastos para formalizacion de tierras'
#  '141130 cafetales - sostenimiento'
#  '307028 compra de productos nacionales para proyectos para la comercializacion agropecuaria'
#  '206015 compra de materia prima e insumos nacionales para proyectos para la transformacion agropecuaria'
#  '408011 compra de productos insumos y servicios para proyectos para la prestacion directa de labores y servicios de apoyo para la produccion agrop'
#  '408013 compra de productos insumos y servicios para proyectos para la prestacion directa de labores y servicios de apoyo a la comercializacion agrop'
#  '408012 compra de productos insumos y servicios para proyectos para la prestacion directa de labores y servicios de apoyo a la transformacion agrop'
#  '109002 infraestructura maquinaria y equipos para tursimo ecologico'
#  '102002 agroforesteria' '111650 trigo' '841200 investigacion tecnologica'
#  '101056 flores de ciclo corto' '151940 mangostino'
#  '121620 estropajo - ciclo corto - siembra'
#  '105003 equipos para el manejo sosteble del agua'
#  '920001 cannabis medicinal e industrial'
#  '191000 prima seguro agropecuario'
#  '121600 pepino - ciclo corto - siembra'
#  '108002 capitalizacion adquisicion y creacion de empresas de bioeconomia'
#  '109001 turismo ecologico'
#  '102001 agricultura organica ecologica y biologica'
#  '920009 reproduccion y sostenimiento pirarucu lec' '121390 repollo'
#  '111450 mani']
#
#
# +===============================================================================+
# Cada uno de los elementos de la columna GENERO son los siguientes:
# +===============================================================================+
#
#
#  ['h' 'm' 's']

# %% [markdown]
# ####**Comentario 1**
# - Se puede observar que lo cambio quedaron bien aplicados.
# - todos los formatos corresponde a los deseados.
#
# **Detalles a revisar:**
# - Se recomienda eliminar los Id que aparecen en la data, debido que no son significativos, ya que no se va cruzar tablas y adicional la información que representan aparece reflejada.
# - La columna DESTINO_DE_CREDITO esta concatenada con id de rubro, esta información no seria necesaria, lo cual se recomienda borrar.
# - La columna LINEA_DE_PRODUCCION tiene en cada uno de los elementos la seña (i) que indica que pertenece a la linea de credito inversión y la seña (ct) que pertenece a la linea de credito capital de trabajo, se recomienda en este caso eliminar estas señas debido a que hay una columna que especifica esto.

# %% [markdown]
# ####**1.4.2.3- Eliminación de columnas y transformación de columnas**
#
# Se aplican recomendaciones del comentario 1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850141 entries, 0 to 850140
# Data columns (total 28 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   año                                    850141 non-null  int64
#  1   mes                                    850141 non-null  int64
#  2   fuente_colocacion                      850141 non-null  object
#  3   id_tipo_prod                           850141 non-null  int64
#  4   tipo_productor                         850141 non-null  object
#  5   valor_inversion                        850141 non-null  float64
#  6   colocacion                             850141 non-null  float64
#  7   id_depto                               850141 non-null  int64
#  8   departamento_inversion                 850141 non-null  object
#  9   id_munic                               850141 non-null  object
#  10  municipio_inversion                    850141 non-null  object
#  11  municipio_de_postconflico?             850141 non-null  object
#  12  depcol                                 850141 non-null  int64
#  13  departamento_de_colocacion_de_credito  850141 non-null  object
#  14  muncol                                 850141 non-null  object
#  15  municipio_colocacion_de_credito        850141 non-null  object
#  16  plazo                                  850141 non-null  int64
#  17  linea_de_credito                       850141 non-null  object
#  18  linea_de_produccion                    850141 non-null  object
#  19  id_rubro                               850141 non-null  object
#  20  destino_de_credito                     850141 non-null  object
#  21  genero                                 850141 non-null  object
#  22  %_fag                                  543262 non-null  float64
#  23  vlr_inic_garantia                      543262 non-null  float64
#  24  latitud                                850141 non-null  float64
#  25  longitud                               850141 non-null  float64
#  26  cantidad                               850141 non-null  int64
#  27  fecha                                  850141 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(6), int64(7), object(14)
# memory usage: 181.6+ MB

# %%
#1ero se transforma la columna destino_de_credito para proceder con la eliminación de variables

#se coloca la columna id_rubro en el mismo formato como aparece en destino_de_credito, por lo cual se le quita la coma.

data["id_rubro"] = data["id_rubro"].str.replace(",","")

# %%
#Se itera cada elemento de la columna destino credito y se remplaza id_rubro por nada para limpiar elementos de esta columna.
for i, row in data.iterrows():

  data.at[i, 'destino_de_credito'] = row['destino_de_credito'].replace(row['id_rubro'], '').strip()

# %%
#se comprueban cambios
data['destino_de_credito'].unique()
# Out:
# array(['retencion de vientres ganado bovino', 'aguacate',
#        'construccion beneficiaderos de cafe', 'cacao', 'cana panelera',
#        'cafe', 'fresas', 'sandia', 'arroz riego', 'citricos',
#        'maquinaria y equipos', 'sostenimiento cafe', 'papa', 'platano',
#        'capital de trabajo - microcredito agropecuario y rural',
#        'cana panelera - siembra', 'renovacion cacao', 'maiz amarillo',
#        'costos operativos y de funcionamiento para la comercializacion',
#        'platano - sostenimiento',
#        'costos operativos y de funcionamiento para los prestadores de servicios de apoyo para prod',
#        'sostenimiento ceba bovina',
#        'reparacion de infraestructura y de maquinaria para la transformacion',
#        'capital de trabajo - unidad productiva campesina', 'uchuva',
#        'equipos y sistemas nuevos para riego y drenaje',
#        'construccion infraestructura para la produccion pecuaria',
#        'otros cultivos perennes - sostenimiento', 'pastos  y forrajes',
#        'flores',
#        'costos operativos y de funcionamiento para los prestadores de servicios de apoyo para comer',
#        'reparacion infraestructura agricola', 'cebolla cabezona',
#        'maiz blanco', 'electrificacion',
#        'costos operativos y de funcionamiento para la transformacion',
#        'cultivos, mantenimiento etapa improductiva (perennes)',
#        'construccion vivienda campesina', 'cultivos de silvopastoreo',
#        'reparacion de vivienda campesina', 'compra de cartera',
#        'cafe tecnificado - sostenimiento', 'platano - siembra',
#        'costo promedio adquisiciones, cartera, inventarios y costos directos para la trasformacion primaria o comercializacion',
#        'aguacate - siembra',
#        'compra de transporte no especializado nuevo',
#        'sostenimiento cana panelera',
#        'capital de trabajo agropecuario y rural',
#        'maquinaria y equipos produccion insumos',
#        'infraestructura - construccion - produccion pecuaria',
#        'sostenimiento de bovinos cria y doble proposito',
#        'equipos y sistemas de riego - nuevo',
#        'turismo rural capital de trabajo',
#        'compra de transporte especializado', 'cacao - siembra',
#        'consolidacion de pasivos', 'tierra uso agropecuario - compra',
#        'cafe - renovacion', 'bosques - siembra', 'caucho - siembra',
#        'transporte no especializado - compra - transformacion primaria o comercializacion',
#        'construccion, compra de infraestructuras para servicios de apoyo',
#        'infraestructura, maquinaria y equipos para turismo rural',
#        'cafe - siembra', 'cana panelera - renovacion',
#        'citricos - siembra',
#        'cultivos - mantenimiento etapa improductiva - perennes',
#        'beneficiadero de cafe - construccion',
#        'compra de maquinaria y equipos nuevos o usados para servicios de apoyo',
#        'palma - de aceite - siembra', 'campamentos - reparacion',
#        'reestructuracion 1%', 'reestructuracion 2%', 'pina - siembra',
#        'equipo y maquinaria usada', 'pina',
#        'reparacion infraestructura pecuaria - produccion pecuaria - reparacion',
#        'maquinaria y equipos - nuevo - transformacion primaria y comercializacion',
#        'equipos nuevos para produccion pecuaria',
#        'construccion y compra de infraestructura para la comercializacion',
#        'costos operativos y de funcionamiento proyectados.',
#        'construccion y compra de infraestructura para la trasformacion primaria o comercializacion',
#        'cartera. inventarios y costos directos - transformacion primaria o comercializacion',
#        'construccion infraestructura agricola',
#        'construccion y compra de infraestructura para la transformacion',
#        'costos operativos y de funcionamiento para los prestadores de servicios de apoyo para trans',
#        'combinadas nuevas',
#        'capital de trabajo - artesanias - comercializacion', 'bodegas',
#        'granadilla - perennes - siembra',
#        'costo promedio compras - transformacion primaria o comercializacion',
#        'renovacion cafe por zoca',
#        'compra de tierra para uso agropecuario',
#        'reparacion de maquinaria y equipos',
#        'reparacion de infraestructuras para servicios de apoyo',
#        'retencion vientres bovinos leche y bufalos',
#        'sostenimiento de porcinos', 'reparacion infraestructura pecuaria',
#        'tractores nuevos', 'comercializacion de ganado',
#        'fuentes de energia no convencionales renovables',
#        'infraestructura - reparacion - transformacion primaria o comercializacion',
#        'extraccion y comercializacion minera capital de trabajo',
#        'construccion campamentos',
#        'costos operativos y de funcionamiento proyectados - servicios de apoyo a la produccion',
#        'construccion carreteables y puentes',
#        'infraestructura - construccion, adquisicion - transformacion primaria o comercializacion',
#        'maranon', 'maracuya - siembra',
#        'vivienda campesina - diferente a vis - reparacion',
#        'obras civiles para drenaje - construccion',
#        'reparacion obras civiles manejo recurso hidrico en proyectos pecuarios. acuicolas y pesca',
#        'reparacion de infraestructura y de maquinaria para la comercializacion',
#        'papa - siembra', 'invernaderos agricolas - construccion',
#        'unidades y redes de frio',
#        'construccion obras civiles para suministro de agua -           produccion pecuaria o acuicola',
#        'equipos nuevos para acuicultura y pesca', 'avicultura - engorde',
#        'avicultura engorde', 'palma de chontaduro', 'papaya',
#        'obras civiles para suministro de agua - construccion - produccion pecuaria o acuicola',
#        'cartera. inventarios y costos directos - servicios de apoyo a la produccion',
#        'avicultura huevos', 'mango', 'trapiches paneleros - construccion',
#        'renovacion cafe por siembra',
#        'produccion y comercializacion de artesanias',
#        'implementos y equipos nuevos para la produccion agricola',
#        'maquinaria pesada nueva para uso agropecuario.', 'porcinos ceba',
#        'frutales perennes  sostenimiento',
#        'sostenimiento palma de aceite',
#        'infraestructura, maquinaria y equipos para mineria',
#        'sostenimiento acuicultura engorde',
#        'comercializacion de ganado para la transformacion primaria o comercializacion',
#        'construccion obras civiles para riego', 'frijol',
#        'prog. informatica - compra - transformacion y/o comercializacion',
#        'sostenimiento bovinos leche y bufalinos',
#        'construccion infraestructura pesquera y acuicola para la produccion pecuaria',
#        'factoring agropecuario',
#        'infraestructura - construccion, adquisicion - servicios de apoyo a la produccion',
#        'vientres bovinos y bufalinos comerciales cria y d.p',
#        'vientres bovinos comerciales leche', 'lulo - siembra', 'lulo',
#        'compra de porcinos puros', 'maquinaria y equipos usados',
#        'adecuacion de tierras para uso agropecuario',
#        'compra de equipos y programas informaticos', 'redes frio',
#        'arroz secano',
#        'construccion y compra de infraestructura para forestales para la transformacion',
#        'tomate', 'avicultura - huevos', 'sostenimiento de cacao',
#        'retencion vientres bovinos cria y d.p',
#        'bovino - comercial - compra - hembra', 'yuca - siembra',
#        'sostenimiento de banano', 'sostenimiento cana de azucar',
#        'cana de azucar',
#        'construccion obras civiles control de inundaciones',
#        'infraestructura - turismo rural', 'cria de porcinos',
#        'bovino - retencion vientres',
#        'vientres bovinos comreciales cria y d. p. - comercial - compra - hembra',
#        'palma de aceite',
#        'transporte no especializado - nuevo - servicios de apoyo a la produccion',
#        'unidades y redes de frio - nuevo - transformacion primaria',
#        'aguacate hass', 'cana de azucar - sostenimiento',
#        'bovinos y bufalinos machos',
#        'maquinaria y equipos - nuevo - servicios de apoyo a la produccion',
#        'cebolla de hoja - ciclo corto - siembra', 'cacao - renovacion',
#        'carreteables y puentes - construccion', 'sostenimiento caucho',
#        'palma - sostenimiento', 'porcino - compra - cria',
#        'obras civiles para riego - construccion',
#        'ovinos y caprinos - compra', 'mora', 'fique',
#        'pero - perennes - siembra', 'otros cultivos tardio rendimiento',
#        'curuba', 'guanabana - siembra', 'ciruelo', 'tomate de arbol',
#        'cafe por zoca - renovacion',
#        'retencion de vientres de ganado bovino y bufalino - retencion vientres',
#        'banano', 'durazno', 'mora - siembra', 'granadilla',
#        'animal de labor - compra', 'otros cultivos - perennes - siembra',
#        'bodegas manejo post-cosecha', 'compra animales de labor',
#        'maiz - amarillo tradicional - clima frio y medio - siembra',
#        'guayaba', 'bufalino - retencion vientres',
#        'tomate de arbol - perennes - siembra', 'banano - siembra',
#        'palma - de chontaduro - siembra - siembra',
#        'avicultura - reproduccion', 'caucho',
#        'frutales - perennes - sostenimiento',
#        'reparacion de maquinaria y embarcaciones - usado',
#        'cafetales envejecidos - renovacion', 'vid', 'soya',
#        'compra ovinos y caprinos',
#        'sostenimiento especies menores y zoocria', 'arroz - siembra',
#        'haba', 'plantas medicinales y ornamentales',
#        'bovino - sostenimiento', 'pimenton',
#        'cebolla cabezona - ciclo corto - siembra', 'bosques',
#        'otros cultivos mediano rendimiento',
#        'reproduccion para acuicultura y camaronicultura', 'viveros',
#        'yuca', 'algodon', 'cebolla de hoja', 'arracacha',
#        'otros cultivos', 'adquisicion de insumos',
#        'sostenimiento pastos y forrajes', 'manzano - siembra',
#        'pastos - siembra', 'infraestructura de produccion e insumos',
#        'equipos para acuicultura y pesca',
#        'renovacion cafetales envejecidos',
#        'flores - ciclo largo - siembra',
#        'apicultura, especies menores y zoocria', 'sostenimiento pesca',
#        'arroz secano - siembra',
#        'capital de trabajo - artesanias - produccion', 'lima tahiti',
#        'maquinaria - nuevo - produccion pecuaria o acuicola',
#        'lima - siembra - tahiti', 'equinos asnales y mulares',
#        'tractores - compra', 'pitahaya - siembra', 'mango - siembra',
#        'melon', 'guanabana', 'melon - ciclo corto - siembra',
#        'avicultura', 'aji', 'papaya - siembra',
#        'otros cultivos mediano rendimiento - perennes - siembra',
#        'frijol - siembra', 'maquinaria - nuevo - produccion agricola',
#        'fresas - siembra', 'durazno - siembra',
#        'adecuacion de tierras para cultivos - altillanura de la orinoquia',
#        'maquinaria - usado',
#        'certificaciones de buenas practicas, de origen, iso, normas nacionales o internacionales',
#        'palma - de coco - siembra', 'cana panelera - sostenimiento',
#        'palma de coco',
#        'maquinaria - transformacion primaria o comercializacion - usado',
#        'curuba - perennes - siembra', 'equipos - usado',
#        'arracacha - ciclo corto - siembra',
#        'cafe tradicional - sostenimiento',
#        'recuperacion areas cacaoteras - sostenimiento',
#        'invernaderos agricolas - reparacion',
#        'comercializacion de ganado - transformacion primaria o comercializacion',
#        'uchuva - perennes - siembra', 'compra conejos y curies',
#        'beneficiadero de cafe - reparacion',
#        'maiz  - amarillo tecnificado',
#        'anticipo a productores - transformacion primaria o comercializacion',
#        'name - siembra', 'achira - siembra', 'macadamia',
#        'tomate - siembra', 'habichuela', 'manzano',
#        'obras civiles para drenaje - reparacion', 'maracuya - renovacion',
#        'de banano - renovacion', 'mora - renovacion', 'fique - siembra',
#        'vid - siembra',
#        'maiz  - amarillo tradicional - clima calido y medio - siembra',
#        'mejoramiento de praderas', 'pero - perennes - renovacion',
#        'acuicultura y camaronicultura', 'cacao - sostenimiento',
#        'platano - renovacion', 'ciruelo - siembra',
#        'pimenton      - siembra', 'campamentos - construccion',
#        'otros frutales - perennes - siembra',
#        'maiz  blanco tradicional clima calido - blanco tradicional - clima calido - siembra',
#        'guayaba - siembra', 'cana de azucar - siembra', 'pitahaya',
#        'maracuya', 'construccion obras civiles para drenaje',
#        'reparacion infraestructura pesquera y acuicola', 'name', 'achira',
#        'ajonjoli', 'arveja', 'ahuyama', 'caucho - sostenimiento',
#        'zanahoria - ciclo corto - siembra', 'porcino - sostenimiento',
#        'malanga o yautia', 'conejos y curies - compra',
#        'otros cultivos tardio rendimiento - perennes - sostenimiento',
#        'reparacion obras civiles para riego, drenaje y control de inundaciones',
#        'renovacion cultivos envejecidos de cacao',
#        'reparacion de maquinaria y embarcaciones',
#        'otros equipos de apoyo nuevos para la actividad agropecuaria',
#        'gulupa', 'equipos - turismo rural',
#        'infraestructura - reparacion - servicios de apoyo a la produccion',
#        'renovacion de banano', 'otros frutales perennes',
#        'vientres bovinos puros cria y d. p.',
#        'retencion de vientres ganado bovino - retencion vientres',
#        'mango - renovacion', 'palma - de aceite - renovacion',
#        'reproduccion y sostenimiento tilapia lec',
#        'anticipo a productores por parte de los comercializadores',
#        'capitalizacion y creacion de empresas',
#        'equipos e implementos para suministro de aguas - nuevo - produccion pecuaria o acuicola',
#        'reparacion infraestructura y maquinaria para la transformacion y/o comercializacion',
#        'transporte especializado - compra - transformacion primaria o comercializacion',
#        'arandano',
#        'anticipo a productores por parte de los transformadores',
#        'bovinos cria y doble proposito - sostenimiento',
#        'maiz - amarillo tradicional - clima calido y medio - siembra',
#        'equipos y sistemas usados para riego y drenaje',
#        'bovino - comercial - compra - macho',
#        'vivienda campesina - construccion - diferente a vis',
#        'infraestructura, maquinaria y equipos para la produccion de artesanias',
#        'construccion trapiches paneleros', 'cholupa',
#        'adecuacion de tierras para cultivos - otras regiones',
#        'maiz  - blanco tradicional - clima frio y medio - siembra',
#        'zanahoria', 'aji - ciclo corto - siembra',
#        'equipos e implementos nuevos manejo recurso hidrico en proyectos pecuarios, acuicolas y pesca',
#        'cacao - renovacion cultivos envejecidos',
#        'anticipo a productores para la transformacion primaria o comercializacion',
#        'gulupa - perennes - siembra',
#        'otros cultivos - ciclo corto - siembra',
#        'maquinaria pesada de uso agropecuario - nuevo',
#        'combinadas - nuevo', 'lechuga', 'morera - perennes - renovacion',
#        'maquinaria y equipos - servicios de apoyo a la produccion - usado',
#        'codornices - huevos', 'vientres bovinos puros leche',
#        'vientres bufalos - compra',
#        'infraestructura pesquera y acuicola - construccion - produccion pecuaria',
#        'cultivos de silvopastoreo - siembra',
#        'equipos y sistemas de riego - usado', 'biotecnologica',
#        'pastos semilla - siembra', 'tarjeta agropecuaria',
#        'pago pasivos financieros', 'tabaco - rubio - siembra',
#        'retencion de vientres ganado bufalino',
#        'sostenimiento forestales', 'cholupa    - siembra',
#        'obras civiles control de inundaciones - construccion',
#        'otros equipos de apoyo a la actividad agropecuaria - nuevo',
#        'adecuacion tierras para actividad pesquera y acuicola - otras regiones',
#        'bodegas - reparacion - transformacion primaria o comercializacion',
#        'maquinas y equipos informatica - compra', 'apicultura - compra',
#        'equipos - extraccion - mineria',
#        'capital de trabajo - extraccion - mineria',
#        'porcino - cria - sostenimiento', 'mani - siembra',
#        'infraestructura transformacion c. siembra - construccion',
#        'reestructuracion 3%', 'brevo - siembra',
#        'produccion semillas cultivos c. c.', 'remolacha',
#        'comercializacion de metales y piedras preciosas',
#        'pitahaya - renovacion',
#        'reproduccion y sostenimiento cachama lec', 'champinones',
#        'equipos usados o reparacion de equipos manejo recurso hidrico en proyectos pecuarios,',
#        'papayuela', 'calabaza', 'aji tabasco',
#        'infraestructura  produccion  de artesanias - artesanias - produccion',
#        'reproduccion y sost especies nativas lec',
#        'capital de trabajo - turismo rural',
#        'flores - ciclo largo - sostenimiento', 'pero',
#        'reparacion maquinaria y equipos - transformacion primaria o comercializacion - usado',
#        'feijoa - siembra', 'flores - ciclo corto - siembra', 'cardamomo',
#        'bodegas manejo post/cosecha - reparacion - transformacion primaria o comercializacion',
#        'granadilla - perennes - renovacion', 'vid - renovacion',
#        'flores tropicales - ciclo largo - renovacion',
#        'obras civiles para suministro de agua - produccion agricola - reparacion',
#        'brevo', 'codornices huevos', 'feijoa', 'tabaco rubio',
#        'equinos, asnales y mulares reproductores machos y hembras.',
#        'otros cultivos mr - perennes - sostenimiento',
#        '"equipos usados o reparacion de equipos manejo recurso hidrico en proyectos pecuarios, acuicolas y de pesca"',
#        'cebada', 'ajo', 'esparragos', 'cana de azucar - renovacion',
#        'maiz amarillo tecnificado clima calido', 'brocoli',
#        'vientres bovinos puros leche - compra - hembra - puro',
#        'maiz blanco tecnificado de clima calido',
#        'malanga o yautia - ciclo corto - siembra',
#        'flores tropicales - ciclo largo - siembra',
#        'cafes especiales - siembra', 'banano - sostenimiento',
#        'macadamia - siembra',
#        'renovacion cultivos perennes por afectacion fitosanitaria',
#        'infraestructura - extraccion - mineria',
#        'reproduccion y sostenimiento trucha lec',
#        'bodegas  - construccion', 'quinua', 'arveja - siembra', 'avena',
#        'reparacion infraestructura pesquera y acuicola - produccion pecuaria - reparacion',
#        'quinua   - siembra', 'algodon - siembra',
#        'sandia - ciclo corto - siembra',
#        'capital de trabajo - comercializacion - mineria',
#        'cultivos - perennes - renovacion por afectacion fitosanitaria',
#        'guatila  - siembra', 'tabaco negro',
#        'coco - perennes - sostenimiento',
#        'equipos para comercializacion artesanias',
#        'equipos - artesanias - produccion',
#        'bovino - compra - hembra - puro',
#        'infraestructura - artesanias - comercializacion', 'acuicultura',
#        'insumos - compra', 'pepino', 'apio',
#        'lechuga - ciclo corto - siembra',
#        'uchuva - perennes - renovacion',
#        'habichuela - ciclo corto - siembra', 'reestructuracion 4%',
#        'maiz blanco tecnificado clima calido - blanco tecnificado - clima calido - siembra',
#        'ahuyama  - siembra', 'sorgo',
#        'adecuaciones locativas y medidas de bioseguridad para la prevencion del covid - 19',
#        'badea', 'renovacion palma de aceite',
#        'plantas ornamentales - siembra', 'pago pasivos no financieros',
#        'material vegetal - ciclo corto - siembra',
#        'transporte especializado - nuevo - servicios de apoyo a la produccion',
#        'correccion quimica de suelos', 'asistencia tecnica',
#        'carreteables y puentes - reparacion', 'citricos - renovacion',
#        'obras civiles para suministro de agua - produccion pecuaria o acuicola - reparacion',
#        'infraesructura agricola c. siembra - construccion',
#        'equipos forestales nuevos para la produccion agricola',
#        'bovinos leche y bufalinos - sostenimiento',
#        'tomate de arbol - perennes - renovacion', 'esparragos - siembra',
#        'arandano  - siembra', 'reparacion redes de frio',
#        'sostenimiento de equinos, asnales y mulares',
#        'banano exportadores - siembra', 'guatila', 'apicultura',
#        'pina - renovacion', 'plantas medicinales - siembra',
#        'capital de trabajo agropecuario rural', 'papayuela  - siembra',
#        'gastos para formalizacion de tierras',
#        'cafetales - sostenimiento',
#        'compra de productos nacionales para proyectos para la comercializacion agropecuaria',
#        'compra de materia prima e insumos nacionales para proyectos para la transformacion agropecuaria',
#        'compra de productos insumos y servicios para proyectos para la prestacion directa de labores y servicios de apoyo para la produccion agrop',
#        'compra de productos insumos y servicios para proyectos para la prestacion directa de labores y servicios de apoyo a la comercializacion agrop',
#        'compra de productos insumos y servicios para proyectos para la prestacion directa de labores y servicios de apoyo a la transformacion agrop',
#        'infraestructura maquinaria y equipos para tursimo ecologico',
#        'agroforesteria', 'trigo', 'investigacion tecnologica',
#        'flores de ciclo corto', 'mangostino',
#        'estropajo - ciclo corto - siembra',
#        'equipos para el manejo sosteble del agua',
#        'cannabis medicinal e industrial', 'prima seguro agropecuario',
#        'pepino - ciclo corto - siembra',
#        'capitalizacion adquisicion y creacion de empresas de bioeconomia',
#        'turismo ecologico', 'agricultura organica ecologica y biologica',
#        'reproduccion y sostenimiento pirarucu lec', 'repollo', 'mani'],
#       dtype=object)

# %%
#Se eliminan señas de la columna LINEA_DE_PRODUCCION

#se crea una mascara para identificar elementos con señas a borrar, se utilizan expresiones regulares para buscar 
#expresiones especificas

mask_i = data['linea_de_produccion'].str.contains(r'\(i\)')
mask_ct = data['linea_de_produccion'].str.contains(r'\(ct\)')
mask_n = data['linea_de_produccion'].str.contains(r'\(n\)')

data.loc[mask_i, 'linea_de_produccion'] = data.loc[mask_i, 'linea_de_produccion'].replace(r'\((i)\)', '', regex=True).str.strip()
data.loc[mask_ct, 'linea_de_produccion'] = data.loc[mask_ct, 'linea_de_produccion'].replace(r'\((ct)\)', '', regex=True).str.strip()
data.loc[mask_n, 'linea_de_produccion'] = data.loc[mask_n, 'linea_de_produccion'].replace(r'\((n)\)', '', regex=True).str.strip()

# %%
#se comprueban cambios
data['linea_de_produccion'].unique()
# Out:
# array(['compra de animales', 'siembras', 'infraest y adecu de tierras',
#        'produccion', 'comercializacion', 'sostenimiento', 'microcredito',
#        'servicios de apoyo', 'maquinaria y equipo', 'otras actividades',
#        'actividades rurales', 'consolidacion de pasivos',
#        'tarjeta de credito', 'transformacion'], dtype=object)

# %%
#se escogen las columnas que no generan valor y se eliminan y se asigna data limpia en la variable desembolsos_finagro

delete_data = ["id_tipo_prod","id_depto","id_munic","depcol","muncol","id_rubro"]

desembolsos_finagro = data.drop(delete_data, axis=1)

# %%
#se comprueban cambios en la data
desembolsos_finagro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850141 entries, 0 to 850140
# Data columns (total 22 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   año                                    850141 non-null  int64
#  1   mes                                    850141 non-null  int64
#  2   fuente_colocacion                      850141 non-null  object
#  3   tipo_productor                         850141 non-null  object
#  4   valor_inversion                        850141 non-null  float64
#  5   colocacion                             850141 non-null  float64
#  6   departamento_inversion                 850141 non-null  object
#  7   municipio_inversion                    850141 non-null  object
#  8   municipio_de_postconflico?             850141 non-null  object
#  9   departamento_de_colocacion_de_credito  850141 non-null  object
#  10  municipio_colocacion_de_credito        850141 non-null  object
#  11  plazo                                  850141 non-null  int64
#  12  linea_de_credito                       850141 non-null  object
#  13  linea_de_produccion                    850141 non-null  object
#  14  destino_de_credito                     850141 non-null  object
#  15  genero                                 850141 non-null  object
#  16  %_fag                                  543262 non-null  float64
#  17  vlr_inic_garantia                      543262 non-null  float64
#  18  latitud                                850141 non-null  float64
#  19  longitud                               850141 non-null  float64
#  20  cantidad                               850141 non-null  int64
#  21  fecha                                  850141 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(6), int64(4), object(11)
# memory usage: 142.7+ MB

# %% [markdown]
# ####**Comentario 2**
#
# Se logra una limpieza de datos satisfactoria, sin embargo se considera que la data limpia, debe guardarse en nuestro gestor de base de datos de postgreSQL para consultarla directamente, esto con el fin de que no toque ejecutar todo el script del notebook para llegar al dataset objetivo.

# %% [markdown]
# ##**1.5- Carga de data limpia en postgreSQL**

# %%
#Se sube la data limpia a postgreSQL para consultarla directamente
with engine.connect() as conn:
    desembolsos_finagro.to_sql(
            name="desembolsos_2",
            con=conn,
            if_exists="replace",
            index=False,
            method="multi",
            chunksize=2000
            )
